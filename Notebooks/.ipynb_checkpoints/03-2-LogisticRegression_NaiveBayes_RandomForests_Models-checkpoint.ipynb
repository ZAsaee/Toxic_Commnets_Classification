# %% [markdown]
# # Modeling - Classification Algorithms

# %% [markdown]
# ## Table of Contents:
# [1. Import Train and Test Set](#1.-Import-Train-and-Test-Set)
# <br>[2. Classifiers](#2.-Classifiers)
# <br>&emsp;&emsp;&emsp;[2.1.1. TF-IDF and Logistic Regression](#2.1.1.-TF-IDF-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;[2.1.2. TF-IDF, Random Oversampler and Logistic Regression](#2.1.2.-TF-IDF,-Random-Oversampler-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;[2.1.3. TF-IDF, SMOTE Oversampling and Logistic Regression](#2.1.3.-TF-IDF,-SMOTE-Oversampling-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;[2.1.4. TF-IDF, Random Undersampler and Logistic Regression](#2.1.4.-TF-IDF,-Random-Undersampler-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;[2.1.5. TF-IDF, NearMiss Undersampler and Logistic Regression](#2.1.5.-TF-IDF,-NearMiss-Undersampler-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;[2.1.6. Countvectorizer and Logistic Regression](#2.1.6.-Countvectorizer-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;[2.1.7. Countvectorizer, Random Oversampler and Logistic Regression](#2.1.7.-Countvectorizer,-Random-Oversampler-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;[2.1.8. Countvectorizer, SMOTE Oversampler and Logistic Regression](#2.1.8.-Countvectorizer,-SMOTE-Oversampler-and-Logistic-Regression)
# <br>[2.2. Naive Bayes](#2.2.-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;[2.2.1. TFIDF and Naive Bayes](#2.2.1.-TFIDF-and-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;[2.2.2. TFIDF, Random Oversampler and Naive Bayes](#2.2.2.-TFIDF,-Random-Oversampler-and-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;[2.2.3. TFIDF, SMOTE and Naive Bayes](#2.2.3.-TFIDF,-SMOTE-and-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;[2.2.4. TFIDF, Random Undersampler and Naive Bayes](#2.2.4.-TFIDF,-Random-Undersampler-and-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;[2.2.5. TF-IDF, NearMiss Undersampler and Naive Bayes](#2.2.5.-TF-IDF,-NearMiss-Undersampler-and-Naive-Bayes)
# <br>[2.3. Random Forests](#2.3.-Random-Forests)
# <br>&emsp;&emsp;&emsp;[2.3.1. TF-IDF and Random Forests](#2.3.1.-TF-IDF-and-Random-Forests)
# <br>&emsp;&emsp;&emsp;[2.3.2. TF-IDF, Random Oversampler and Random Forests](#2.3.2.-TF-IDF,-Random-Oversampler-and-Random-Forests)
# <br>[3. Summary of Results](#3.-Summary-of-Results)

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
from sklearn.utils.fixes import loguniform
from itertools import cycle
from timeit import default_timer as timer

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
# from lightgbm import LGBMClassifier
from sklearn import naive_bayes
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.pipeline import Pipeline

from sklearn.metrics import classification_report
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import RocCurveDisplay


from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.metrics import precision_recall_fscore_support

from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import NearMiss
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek

from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

from Bayes_Opt_Classification import bayes_kfold_pipeline

# %% [markdown]
# ## 1. Import Train and Test Set

# %%
df = pd.read_csv('Library/cleaned_text_train_df.csv')
df.head()
# Out:
#                                           clean_text  toxic_type
# 0  explanation edit make username hardcore metall...           0
# 1  aww match background colour seemingly stuck th...           0
# 2  hey man really not try edit war guy constantly...           0
# 3  make real suggestion improvement wonder sectio...           0
# 4                      sir hero chance remember page           0

# %%
df.isna().sum()
# Out:
# clean_text    54
# toxic_type     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df_test = pd.read_csv('Library/cleaned_text_test_df.csv')
df_test.head()
# Out:
#                                           clean_text  toxic_type
# 0  thank understand think highly would not revert...           0
# 1                             dear god site horrible           0
# 2  somebody invariably try add religion really me...           0
# 3  say right type type institution need case thre...           0
# 4  add new product list make sure relevant add ne...           0

# %%
df_test.isna().sum()
# Out:
# clean_text    437
# toxic_type      0
# dtype: int64

# %%
df_test = df_test.dropna()

# %%
df_test.head()
# Out:
#                                           clean_text  toxic_type
# 0  thank understand think highly would not revert...           0
# 1                             dear god site horrible           0
# 2  somebody invariably try add religion really me...           0
# 3  say right type type institution need case thre...           0
# 4  add new product list make sure relevant add ne...           0

# %%
X_train = df['clean_text']
y_train = df['toxic_type']

X_test = df_test['clean_text']
y_test = df_test['toxic_type']

summary_dic ={}

# %% [markdown]
# ## 2. Classifiers

# %% [markdown]
# ### 2.1. Logistic Regression

# %% [markdown]
# ### 2.1.1. TF-IDF and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
#     'clf__dual': (True, False),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = None

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'None'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR1'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=30,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 266 seconds elapsed.
# total iterations will be taken to explore all subspaces:  60
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 10.539293459333894
# 	tfidf__max_features: 24831
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99    143292
#            1       0.94      0.81      0.87     16225
#
#     accuracy                           0.98    159517
#    macro avg       0.96      0.90      0.93    159517
# weighted avg       0.98      0.98      0.97    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96     57298
#            1       0.57      0.81      0.67      6243
#
#     accuracy                           0.92     63541
#    macro avg       0.78      0.87      0.81     63541
# weighted avg       0.94      0.92      0.93     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR1'].append('LR1')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR1']))
f.close()

# %% [markdown]
# ### 2.1.2. TF-IDF, Random Oversampler and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
    'over__sampling_strategy': (0.3, 1),
#     'over__shrinkage': Real(0,0.9),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('over', RandomOverSampler())

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Oversampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR2'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=30,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=-1,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 492 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 4.059412074131712
# 	over__sampling_strategy: 0.3
# 	tfidf__max_features: 30000
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99    143292
#            1       0.87      0.89      0.88     16225
#
#     accuracy                           0.98    159517
#    macro avg       0.93      0.94      0.93    159517
# weighted avg       0.98      0.98      0.98    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.95     57298
#            1       0.51      0.86      0.64      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.89      0.79     63541
# weighted avg       0.94      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR2'].append('LR2')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR2']))
f.close()

# %% [markdown]
# ### 2.1.3. TF-IDF, SMOTE Oversampling and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
    'over__sampling_strategy': (0.3, 1),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('over', SMOTE())

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'SMOTE'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR3'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=30,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 821 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 0.9902316259691957
# 	over__sampling_strategy: 0.3
# 	tfidf__max_features: 30000
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98    143292
#            1       0.84      0.81      0.82     16225
#
#     accuracy                           0.97    159517
#    macro avg       0.91      0.90      0.90    159517
# weighted avg       0.96      0.97      0.96    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94     57298
#            1       0.50      0.88      0.64      6243
#
#     accuracy                           0.90     63541
#    macro avg       0.74      0.89      0.79     63541
# weighted avg       0.94      0.90      0.91     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR3'].append('LR3')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR3']))
f.close()

# %% [markdown]
# ### 2.1.4. TF-IDF, Random Undersampler and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
    'under__sampling_strategy': (0.3, 1),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('under', RandomUnderSampler())

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Undersampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR4'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=30,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 396 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 6.069853122045976
# 	tfidf__max_features: 30000
# 	under__sampling_strategy: 0.3
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98    143292
#            1       0.84      0.88      0.86     16225
#
#     accuracy                           0.97    159517
#    macro avg       0.91      0.93      0.92    159517
# weighted avg       0.97      0.97      0.97    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94     57298
#            1       0.50      0.88      0.64      6243
#
#     accuracy                           0.90     63541
#    macro avg       0.74      0.89      0.79     63541
# weighted avg       0.94      0.90      0.91     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR4'].append('LR4')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR4']))
f.close()

# %% [markdown]
# ### 2.1.5. TF-IDF, NearMiss Undersampler and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
    'under__sampling_strategy': (0.3, 1),
    'under__n_neighbors': (3,10),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('under', NearMiss())

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Undersampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR5'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=30,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 3075 seconds elapsed.
# total iterations will be taken to explore all subspaces:  200
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 5.306005235133345
# 	tfidf__max_features: 23734
# 	under__n_neighbors: 3
# 	under__sampling_strategy: 0.3
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98    143292
#            1       0.86      0.85      0.85     16225
#
#     accuracy                           0.97    159517
#    macro avg       0.92      0.92      0.92    159517
# weighted avg       0.97      0.97      0.97    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.95     57298
#            1       0.52      0.86      0.64      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.88      0.80     63541
# weighted avg       0.94      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR5'].append('LR5')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR5']))
f.close()

# %% [markdown]
# ### 2.1.6. Countvectorizer and Logistic Regression

# %%
parameters = {
    'count__max_features': (1000, 30000),
#     'clf__dual': (True, False),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('count', CountVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = None

classifier_name = 'Logistic Regression'
text_vec_name = 'CountVectorizer'
resample_method_name = 'None'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR6'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=30,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 681 seconds elapsed.
# total iterations will be taken to explore all subspaces:  100
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 100.0
# 	count__max_features: 14356
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97    143292
#            1       0.92      0.59      0.72     16225
#
#     accuracy                           0.95    159517
#    macro avg       0.94      0.79      0.85    159517
# weighted avg       0.95      0.95      0.95    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     57298
#            1       0.63      0.62      0.62      6243
#
#     accuracy                           0.93     63541
#    macro avg       0.79      0.79      0.79     63541
# weighted avg       0.93      0.93      0.93     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR6'].append('LR6')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR6']))
f.close()

# %% [markdown]
# ### 2.1.7. Countvectorizer, Random Oversampler and Logistic Regression

# %%
parameters = {
    'count__max_features': (1000, 30000),
    'over__sampling_strategy': (0.3, 1),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('count', CountVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('over', RandomOverSampler())

classifier_name = 'Logistic Regression'
text_vec_name = 'CountVectorizer'
resample_method_name = 'Random Oversampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR7'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=30,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 875 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 0.5613687352847552
# 	count__max_features: 25796
# 	over__sampling_strategy: 0.48383767822140333
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98    143292
#            1       0.79      0.83      0.81     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.89      0.90      0.89    159517
# weighted avg       0.96      0.96      0.96    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94     57298
#            1       0.49      0.86      0.63      6243
#
#     accuracy                           0.90     63541
#    macro avg       0.74      0.88      0.78     63541
# weighted avg       0.94      0.90      0.91     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR7'].append('LR7')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR7']))
f.close()

# %% [markdown]
# ### 2.1.8. Countvectorizer, SMOTE Oversampler and Logistic Regression

# %%
parameters = {
    'count__max_features': (1000, 30000),
    'over__sampling_strategy': (0.3, 1),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('count', CountVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('over', SMOTE())

classifier_name = 'Logistic Regression'
text_vec_name = 'CountVectorizer'
resample_method_name = 'SMOTE'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR8'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=30,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 1028 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 10.946209113160949
# 	count__max_features: 30000
# 	over__sampling_strategy: 0.3
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    143292
#            1       0.83      0.74      0.78     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.90      0.86      0.88    159517
# weighted avg       0.96      0.96      0.96    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95     57298
#            1       0.53      0.81      0.64      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.87      0.80     63541
# weighted avg       0.93      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR8'].append('LR8')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR8']))
f.close()

# %% [markdown]
# ## 2.2. Naive Bayes

# %% [markdown]
# ### 2.2.1. TFIDF and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
#     'over__sampling_strategy': (0.3, 1),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = None

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'None'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR9'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 340 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	tfidf__max_features: 6076
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97    143292
#            1       0.94      0.55      0.70     16225
#
#     accuracy                           0.95    159517
#    macro avg       0.94      0.77      0.83    159517
# weighted avg       0.95      0.95      0.95    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     57298
#            1       0.70      0.60      0.65      6243
#
#     accuracy                           0.94     63541
#    macro avg       0.83      0.79      0.80     63541
# weighted avg       0.93      0.94      0.93     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR9'].append('LR9')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR9']))
f.close()

# %% [markdown]
# ### 2.2.2. TFIDF, Random Oversampler and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
    'over__sampling_strategy': (0.3, 1),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = ('over', RandomOverSampler())

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Oversampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR10'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 351 seconds elapsed.
# total iterations will be taken to explore all subspaces:  200
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	over__sampling_strategy: 0.32969374394831763
# 	tfidf__max_features: 14404
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    143292
#            1       0.78      0.77      0.78     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.88      0.88      0.88    159517
# weighted avg       0.96      0.96      0.96    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95     57298
#            1       0.52      0.79      0.63      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.86      0.79     63541
# weighted avg       0.93      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR10'].append('LR10')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR10']))
f.close()

# %% [markdown]
# ### 2.2.3. TFIDF, SMOTE and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
    'over__sampling_strategy': (0.3, 1),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = ('over', SMOTE())

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'SMOTE'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR11'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 679 seconds elapsed.
# total iterations will be taken to explore all subspaces:  200
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	over__sampling_strategy: 0.3695207688160904
# 	tfidf__max_features: 16467
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97    143292
#            1       0.78      0.78      0.78     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.88      0.88      0.88    159517
# weighted avg       0.95      0.96      0.95    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95     57298
#            1       0.52      0.80      0.63      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.86      0.79     63541
# weighted avg       0.93      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR11'].append('LR11')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR11']))
f.close()

# %% [markdown]
# ### 2.2.4. TFIDF, Random Undersampler and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
    'under__sampling_strategy': (0.3, 1),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = ('under', RandomUnderSampler())

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Undersampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR12'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 349 seconds elapsed.
# total iterations will be taken to explore all subspaces:  200
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	tfidf__max_features: 20723
# 	under__sampling_strategy: 0.37072106522090753
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    143292
#            1       0.80      0.75      0.77     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.89      0.87      0.88    159517
# weighted avg       0.95      0.96      0.95    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95     57298
#            1       0.53      0.79      0.63      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.86      0.79     63541
# weighted avg       0.93      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR12'].append('LR12')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR12']))
f.close()

# %% [markdown]
# ### 2.2.5. TF-IDF, NearMiss Undersampler and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
    'under__sampling_strategy': (0.3, 1),
    'under__n_neighbors': (3,10),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = ('under', NearMiss())

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'Near Miss'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR13'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 2755 seconds elapsed.
# total iterations will be taken to explore all subspaces:  250
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	tfidf__max_features: 10320
# 	under__n_neighbors: 10
# 	under__sampling_strategy: 0.3437884943892614
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    143292
#            1       0.81      0.74      0.77     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.89      0.86      0.87    159517
# weighted avg       0.95      0.96      0.95    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95     57298
#            1       0.53      0.80      0.64      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.86      0.79     63541
# weighted avg       0.93      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR13'].append('LR13')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR13']))
f.close()

# %% [markdown]
# ## 2.3. Random Forests

# %% [markdown]
# ### 2.3.1. TF-IDF and Random Forests

# %%
parameters = {
    'tfidf__max_features': (1000, 20000),
#     'under__sampling_strategy': (0.3, 1),
#     'under__n_neighbors': (3,10),
    'clf__n_estimators': (100,500),
    'clf__max_depth': (50, 200),
    'clf__max_features': ('sqrt','log2'),
#     'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', RandomForestClassifier())
resample = None

classifier_name = 'Random Forests'
text_vec_name = 'TF-IDF'
resample_method_name = None

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR14'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=2, bayes_n_iter=40,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=-1,  resample=resample))
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# 5849 seconds elapsed.
# total iterations will be taken to explore all subspaces:  120
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__max_depth: 200
# 	clf__max_features: 'sqrt'
# 	clf__n_estimators: 500
# 	tfidf__max_features: 5009
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    143292
#            1       1.00      0.89      0.94     16225
#
#     accuracy                           0.99    159517
#    macro avg       0.99      0.94      0.97    159517
# weighted avg       0.99      0.99      0.99    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96     57298
#            1       0.57      0.81      0.67      6243
#
#     accuracy                           0.92     63541
#    macro avg       0.78      0.87      0.81     63541
# weighted avg       0.94      0.92      0.93     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR14'].append('LR14')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR14']))
f.close()

# %% [markdown]
# ### 2.3.2. TF-IDF, Random Oversampler and Random Forests

# %%
parameters = {
    'tfidf__max_features': (1000, 9000),
    'over__sampling_strategy': (0.3, 0.7),
#     'under__n_neighbors': (3,10),
    'clf__n_estimators': (100,500),
    'clf__max_depth': (100, 200),
#     'clf__max_features': ('sqrt'),
#     'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', RandomForestClassifier())
resample = ('over', RandomOverSampler())

classifier_name = 'Random Forests'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Oversampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR15'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=2, bayes_n_iter=40,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=-1,  resample=resample))
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# 25767 seconds elapsed.
# total iterations will be taken to explore all subspaces:  200
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__max_depth: 200
# 	clf__n_estimators: 500
# 	over__sampling_strategy: 0.3
# 	tfidf__max_features: 4459
# ------------------------------------------------------------------
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00    143292
#            1       1.00      0.95      0.97     16225
#
#     accuracy                           0.99    159517
#    macro avg       0.99      0.97      0.98    159517
# weighted avg       0.99      0.99      0.99    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95     57298
#            1       0.55      0.81      0.66      6243
#
#     accuracy                           0.92     63541
#    macro avg       0.77      0.87      0.81     63541
# weighted avg       0.94      0.92      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR15'].append('LR15')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR15']))
f.close()

# %% [markdown]
# ## 3. Summary of Results

# %%
summary_df = pd.read_csv('summary_results', header=None)

# %%
summary_df.head()
# Out:
#           0                       1                       2         3  \
# 0  'TF-IDF'   'Logistic Regression'                  'None'  0.978239
# 1  'TF-IDF'   'Logistic Regression'                  'None'  0.978287
# 2  'TF-IDF'   'Logistic Regression'    'Random Oversampler'  0.983619
# 3  'TF-IDF'   'Logistic Regression'                 'SMOTE'  0.985625
# 4  'TF-IDF'   'Logistic Regression'   'Random Undersampler'  0.985610
#
#           4         5         6         7         8        9
# 0  0.933628  0.955413  0.570574  0.809387  0.669316   'LR1']
# 1  0.934151  0.955710  0.572610  0.809707  0.670825   'LR1']
# 2  0.910660  0.945734  0.512151  0.860804  0.642208   'LR2']
# 3  0.904656  0.943407  0.501096  0.878904  0.638283   'LR3']
# 4  0.903696  0.942877  0.498592  0.878904  0.636248   'LR4']

# %%
summary_df = summary_df.drop(columns=9, axis=1)

# %%
summary_df.columns = ['Text Vectorization','Classification Algorithm', 'Resampling Technique',
                     'Precision(non-toxic)', 'Recall(non-toxic)', 'f1-Score(non-toxic)',
                     'Precision(toxic)', 'Recall(toxic)', 'f1-Score(toxic)']

# %% [markdown]
# ### Sort by f1-Score of the Toxic Comments

# %%
summary_df.sort_values(by='f1-Score(toxic)', ascending=False)
# Out:
#    Text Vectorization Classification Algorithm    Resampling Technique  \
# 1            'TF-IDF'    'Logistic Regression'                  'None'
# 14           'TF-IDF'         'Random Forests'                    None
# 0            'TF-IDF'    'Logistic Regression'                  'None'
# 15           'TF-IDF'         'Random Forests'    'Random Oversampler'
# 9            'TF-IDF'            'Naive Bayes'                  'None'
# 5            'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 8   'CountVectorizer'    'Logistic Regression'                 'SMOTE'
# 2            'TF-IDF'    'Logistic Regression'    'Random Oversampler'
# 3            'TF-IDF'    'Logistic Regression'                 'SMOTE'
# 13           'TF-IDF'            'Naive Bayes'             'Near Miss'
# 4            'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 12           'TF-IDF'            'Naive Bayes'   'Random Undersampler'
# 10           'TF-IDF'            'Naive Bayes'    'Random Oversampler'
# 11           'TF-IDF'            'Naive Bayes'                 'SMOTE'
# 7   'CountVectorizer'    'Logistic Regression'    'Random Oversampler'
# 6   'CountVectorizer'    'Logistic Regression'                  'None'
#
#     Precision(non-toxic)  Recall(non-toxic)  f1-Score(non-toxic)  \
# 1               0.978287           0.934151             0.955710
# 14              0.977909           0.934814             0.955876
# 0               0.978239           0.933628             0.955413
# 15              0.978202           0.928881             0.952904
# 9               0.957021           0.971936             0.964421
# 5               0.983206           0.912423             0.946493
# 8               0.978508           0.921725             0.949268
# 2               0.983619           0.910660             0.945734
# 3               0.985625           0.904656             0.943407
# 13              0.976859           0.923121             0.949230
# 4               0.985610           0.903696             0.942877
# 12              0.975814           0.923837             0.949114
# 10              0.975906           0.921795             0.948079
# 11              0.976823           0.918706             0.946873
# 7               0.983374           0.903243             0.941607
# 6               0.958574           0.959527             0.959050
#
#     Precision(toxic)  Recall(toxic)  f1-Score(toxic)
# 1           0.572610       0.809707         0.670825
# 14          0.574019       0.806183         0.670575
# 0           0.570574       0.809387         0.669316
# 15          0.553767       0.810027         0.657821
# 9           0.699439       0.599391         0.645562
# 5           0.516011       0.856960         0.644151
# 8           0.531250       0.814192         0.642970
# 2           0.512151       0.860804         0.642208
# 3           0.501096       0.878904         0.638283
# 13          0.531134       0.799295         0.638189
# 4           0.498592       0.878904         0.636248
# 12          0.530500       0.789845         0.634702
# 10          0.524310       0.791126         0.630658
# 11          0.517406       0.799936         0.628374
# 7           0.491935       0.859843         0.625823
# 6           0.625121       0.619414         0.622254

# %% [markdown]
# ### Sort by Recall of the Toxic Comments

# %%
summary_df.sort_values(by='Recall(toxic)', ascending=False)
# Out:
#    Text Vectorization Classification Algorithm    Resampling Technique  \
# 3            'TF-IDF'    'Logistic Regression'                 'SMOTE'
# 4            'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 2            'TF-IDF'    'Logistic Regression'    'Random Oversampler'
# 7   'CountVectorizer'    'Logistic Regression'    'Random Oversampler'
# 5            'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 8   'CountVectorizer'    'Logistic Regression'                 'SMOTE'
# 15           'TF-IDF'         'Random Forests'    'Random Oversampler'
# 1            'TF-IDF'    'Logistic Regression'                  'None'
# 0            'TF-IDF'    'Logistic Regression'                  'None'
# 14           'TF-IDF'         'Random Forests'                    None
# 11           'TF-IDF'            'Naive Bayes'                 'SMOTE'
# 13           'TF-IDF'            'Naive Bayes'             'Near Miss'
# 10           'TF-IDF'            'Naive Bayes'    'Random Oversampler'
# 12           'TF-IDF'            'Naive Bayes'   'Random Undersampler'
# 6   'CountVectorizer'    'Logistic Regression'                  'None'
# 9            'TF-IDF'            'Naive Bayes'                  'None'
#
#     Precision(non-toxic)  Recall(non-toxic)  f1-Score(non-toxic)  \
# 3               0.985625           0.904656             0.943407
# 4               0.985610           0.903696             0.942877
# 2               0.983619           0.910660             0.945734
# 7               0.983374           0.903243             0.941607
# 5               0.983206           0.912423             0.946493
# 8               0.978508           0.921725             0.949268
# 15              0.978202           0.928881             0.952904
# 1               0.978287           0.934151             0.955710
# 0               0.978239           0.933628             0.955413
# 14              0.977909           0.934814             0.955876
# 11              0.976823           0.918706             0.946873
# 13              0.976859           0.923121             0.949230
# 10              0.975906           0.921795             0.948079
# 12              0.975814           0.923837             0.949114
# 6               0.958574           0.959527             0.959050
# 9               0.957021           0.971936             0.964421
#
#     Precision(toxic)  Recall(toxic)  f1-Score(toxic)
# 3           0.501096       0.878904         0.638283
# 4           0.498592       0.878904         0.636248
# 2           0.512151       0.860804         0.642208
# 7           0.491935       0.859843         0.625823
# 5           0.516011       0.856960         0.644151
# 8           0.531250       0.814192         0.642970
# 15          0.553767       0.810027         0.657821
# 1           0.572610       0.809707         0.670825
# 0           0.570574       0.809387         0.669316
# 14          0.574019       0.806183         0.670575
# 11          0.517406       0.799936         0.628374
# 13          0.531134       0.799295         0.638189
# 10          0.524310       0.791126         0.630658
# 12          0.530500       0.789845         0.634702
# 6           0.625121       0.619414         0.622254
# 9           0.699439       0.599391         0.645562

# %% [markdown]
# ### Sort by Precision of the Toxic Comments

# %%
summary_df.sort_values(by='Precision(toxic)', ascending=False)
# Out:
#    Text Vectorization Classification Algorithm    Resampling Technique  \
# 9            'TF-IDF'            'Naive Bayes'                  'None'
# 6   'CountVectorizer'    'Logistic Regression'                  'None'
# 14           'TF-IDF'         'Random Forests'                    None
# 1            'TF-IDF'    'Logistic Regression'                  'None'
# 0            'TF-IDF'    'Logistic Regression'                  'None'
# 15           'TF-IDF'         'Random Forests'    'Random Oversampler'
# 8   'CountVectorizer'    'Logistic Regression'                 'SMOTE'
# 13           'TF-IDF'            'Naive Bayes'             'Near Miss'
# 12           'TF-IDF'            'Naive Bayes'   'Random Undersampler'
# 10           'TF-IDF'            'Naive Bayes'    'Random Oversampler'
# 11           'TF-IDF'            'Naive Bayes'                 'SMOTE'
# 5            'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 2            'TF-IDF'    'Logistic Regression'    'Random Oversampler'
# 3            'TF-IDF'    'Logistic Regression'                 'SMOTE'
# 4            'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 7   'CountVectorizer'    'Logistic Regression'    'Random Oversampler'
#
#     Precision(non-toxic)  Recall(non-toxic)  f1-Score(non-toxic)  \
# 9               0.957021           0.971936             0.964421
# 6               0.958574           0.959527             0.959050
# 14              0.977909           0.934814             0.955876
# 1               0.978287           0.934151             0.955710
# 0               0.978239           0.933628             0.955413
# 15              0.978202           0.928881             0.952904
# 8               0.978508           0.921725             0.949268
# 13              0.976859           0.923121             0.949230
# 12              0.975814           0.923837             0.949114
# 10              0.975906           0.921795             0.948079
# 11              0.976823           0.918706             0.946873
# 5               0.983206           0.912423             0.946493
# 2               0.983619           0.910660             0.945734
# 3               0.985625           0.904656             0.943407
# 4               0.985610           0.903696             0.942877
# 7               0.983374           0.903243             0.941607
#
#     Precision(toxic)  Recall(toxic)  f1-Score(toxic)
# 9           0.699439       0.599391         0.645562
# 6           0.625121       0.619414         0.622254
# 14          0.574019       0.806183         0.670575
# 1           0.572610       0.809707         0.670825
# 0           0.570574       0.809387         0.669316
# 15          0.553767       0.810027         0.657821
# 8           0.531250       0.814192         0.642970
# 13          0.531134       0.799295         0.638189
# 12          0.530500       0.789845         0.634702
# 10          0.524310       0.791126         0.630658
# 11          0.517406       0.799936         0.628374
# 5           0.516011       0.856960         0.644151
# 2           0.512151       0.860804         0.642208
# 3           0.501096       0.878904         0.638283
# 4           0.498592       0.878904         0.636248
# 7           0.491935       0.859843         0.625823

# %% [markdown]
# ## Ensemble Models Summary

# %%
summary_df_ensemble = pd.read_csv('Ensemble_Summary_Results', header=None)

# %%
summary_df_ensemble = summary_df_ensemble.drop(columns=9, axis=1)

# %%
summary_df_ensemble.columns = ['Text Vectorization','Classification Algorithm', 'Resampling Technique',
                     'Precision(non-toxic)', 'Recall(non-toxic)', 'f1-Score(non-toxic)',
                     'Precision(toxic)', 'Recall(toxic)', 'f1-Score(toxic)']

# %% [markdown]
# ### Sort by f1-Score of the Toxic Comments

# %%
summary_df_ensemble.sort_values(by='f1-Score(toxic)', ascending=False)
# Out:
#    Text Vectorization Classification Algorithm Resampling Technique  \
# 13           'TF-IDF'                   'LGBM'                 None
# 16           'TF-IDF'                   'LGBM'                 None
# 14           'TF-IDF'                   'LGBM'                 None
# 15           'TF-IDF'                   'LGBM'                 None
# 17           'TF-IDF'                   'LGBM'                 None
# 7            'TF-IDF'                   'LGBM'                 None
# 8            'TF-IDF'                   'LGBM'                 None
# 2            'TF-IDF'                'XGBoost'                 None
# 6            'TF-IDF'                'XGBoost'                 None
# 10           'TF-IDF'                   'LGBM'                 None
# 4            'TF-IDF'                'XGBoost'                 None
# 11  'CountVectorizer'                   'LGBM'                 None
# 9            'TF-IDF'                   'LGBM'                 None
# 3            'TF-IDF'                'XGBoost'                 None
# 1            'TF-IDF'         'Random Forests'                 None
# 5            'TF-IDF'                'XGBoost'                 None
# 12           'TF-IDF'                   'LGBM'                 None
# 0            'TF-IDF'         'Random Forests'                 None
#
#     Precision(non-toxic)  Recall(non-toxic)  f1-Score(non-toxic)  \
# 13              0.977081           0.938968             0.957645
# 16              0.977561           0.937485             0.957104
# 14              0.977795           0.936822             0.956870
# 15              0.977830           0.936036             0.956477
# 17              0.975295           0.941150             0.957918
# 7               0.973330           0.944588             0.958744
# 8               0.973239           0.944466             0.958637
# 2               0.970108           0.950417             0.960162
# 6               0.978949           0.930940             0.954341
# 10              0.976693           0.935425             0.955614
# 4               0.972466           0.943104             0.957560
# 11              0.970517           0.945059             0.957619
# 9               0.972424           0.940399             0.956144
# 3               0.984300           0.907082             0.944115
# 1               0.960476           0.957660             0.959066
# 5               0.948564           0.971674             0.959980
# 12              0.987745           0.869350             0.924774
# 0               0.928088           0.993089             0.959489
#
#     Precision(toxic)  Recall(toxic)  f1-Score(toxic)
# 13          0.587521       0.797854         0.676720
# 16          0.583101       0.802499         0.675430
# 14          0.581212       0.804741         0.674951
# 15          0.578348       0.805222         0.673184
# 17          0.591223       0.781195         0.673061
# 7           0.599874       0.762454         0.671463
# 8           0.599093       0.761653         0.670663
# 2           0.616392       0.731219         0.668913
# 6           0.562907       0.816274         0.666318
# 10          0.572946       0.795131         0.665996
# 4           0.591120       0.754926         0.663056
# 11          0.593597       0.736505         0.657374
# 9           0.579951       0.755246         0.656091
# 3           0.504191       0.867211         0.637654
# 1           0.621588       0.638315         0.629840
# 5           0.665154       0.516418         0.581425
# 12          0.429029       0.901009         0.581275
# 0           0.822422       0.293769         0.432905

# %% [markdown]
# ## Final Summary including All Models

# %% [markdown]
# ### Sort by f1-Score

# %%
pd.concat([summary_df, summary_df_ensemble]).sort_values(by='f1-Score(toxic)', ascending=False).reset_index()
# Out:
#     index Text Vectorization Classification Algorithm    Resampling Technique  \
# 0      13           'TF-IDF'                   'LGBM'                    None
# 1      16           'TF-IDF'                   'LGBM'                    None
# 2      14           'TF-IDF'                   'LGBM'                    None
# 3      15           'TF-IDF'                   'LGBM'                    None
# 4      17           'TF-IDF'                   'LGBM'                    None
# 5       7           'TF-IDF'                   'LGBM'                    None
# 6       1           'TF-IDF'    'Logistic Regression'                  'None'
# 7       8           'TF-IDF'                   'LGBM'                    None
# 8      14           'TF-IDF'         'Random Forests'                    None
# 9       0           'TF-IDF'    'Logistic Regression'                  'None'
# 10      2           'TF-IDF'                'XGBoost'                    None
# 11      6           'TF-IDF'                'XGBoost'                    None
# 12     10           'TF-IDF'                   'LGBM'                    None
# 13      4           'TF-IDF'                'XGBoost'                    None
# 14     15           'TF-IDF'         'Random Forests'    'Random Oversampler'
# 15     11  'CountVectorizer'                   'LGBM'                    None
# 16      9           'TF-IDF'                   'LGBM'                    None
# 17      9           'TF-IDF'            'Naive Bayes'                  'None'
# 18      5           'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 19      8  'CountVectorizer'    'Logistic Regression'                 'SMOTE'
# 20      2           'TF-IDF'    'Logistic Regression'    'Random Oversampler'
# 21      3           'TF-IDF'    'Logistic Regression'                 'SMOTE'
# 22     13           'TF-IDF'            'Naive Bayes'             'Near Miss'
# 23      3           'TF-IDF'                'XGBoost'                    None
# 24      4           'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 25     12           'TF-IDF'            'Naive Bayes'   'Random Undersampler'
# 26     10           'TF-IDF'            'Naive Bayes'    'Random Oversampler'
# 27      1           'TF-IDF'         'Random Forests'                    None
# 28     11           'TF-IDF'            'Naive Bayes'                 'SMOTE'
# 29      7  'CountVectorizer'    'Logistic Regression'    'Random Oversampler'
# 30      6  'CountVectorizer'    'Logistic Regression'                  'None'
# 31      5           'TF-IDF'                'XGBoost'                    None
# 32     12           'TF-IDF'                   'LGBM'                    None
# 33      0           'TF-IDF'         'Random Forests'                    None
#
#     Precision(non-toxic)  Recall(non-toxic)  f1-Score(non-toxic)  \
# 0               0.977081           0.938968             0.957645
# 1               0.977561           0.937485             0.957104
# 2               0.977795           0.936822             0.956870
# 3               0.977830           0.936036             0.956477
# 4               0.975295           0.941150             0.957918
# 5               0.973330           0.944588             0.958744
# 6               0.978287           0.934151             0.955710
# 7               0.973239           0.944466             0.958637
# 8               0.977909           0.934814             0.955876
# 9               0.978239           0.933628             0.955413
# 10              0.970108           0.950417             0.960162
# 11              0.978949           0.930940             0.954341
# 12              0.976693           0.935425             0.955614
# 13              0.972466           0.943104             0.957560
# 14              0.978202           0.928881             0.952904
# 15              0.970517           0.945059             0.957619
# 16              0.972424           0.940399             0.956144
# 17              0.957021           0.971936             0.964421
# 18              0.983206           0.912423             0.946493
# 19              0.978508           0.921725             0.949268
# 20              0.983619           0.910660             0.945734
# 21              0.985625           0.904656             0.943407
# 22              0.976859           0.923121             0.949230
# 23              0.984300           0.907082             0.944115
# 24              0.985610           0.903696             0.942877
# 25              0.975814           0.923837             0.949114
# 26              0.975906           0.921795             0.948079
# 27              0.960476           0.957660             0.959066
# 28              0.976823           0.918706             0.946873
# 29              0.983374           0.903243             0.941607
# 30              0.958574           0.959527             0.959050
# 31              0.948564           0.971674             0.959980
# 32              0.987745           0.869350             0.924774
# 33              0.928088           0.993089             0.959489
#
#     Precision(toxic)  Recall(toxic)  f1-Score(toxic)
# 0           0.587521       0.797854         0.676720
# 1           0.583101       0.802499         0.675430
# 2           0.581212       0.804741         0.674951
# 3           0.578348       0.805222         0.673184
# 4           0.591223       0.781195         0.673061
# 5           0.599874       0.762454         0.671463
# 6           0.572610       0.809707         0.670825
# 7           0.599093       0.761653         0.670663
# 8           0.574019       0.806183         0.670575
# 9           0.570574       0.809387         0.669316
# 10          0.616392       0.731219         0.668913
# 11          0.562907       0.816274         0.666318
# 12          0.572946       0.795131         0.665996
# 13          0.591120       0.754926         0.663056
# 14          0.553767       0.810027         0.657821
# 15          0.593597       0.736505         0.657374
# 16          0.579951       0.755246         0.656091
# 17          0.699439       0.599391         0.645562
# 18          0.516011       0.856960         0.644151
# 19          0.531250       0.814192         0.642970
# 20          0.512151       0.860804         0.642208
# 21          0.501096       0.878904         0.638283
# 22          0.531134       0.799295         0.638189
# 23          0.504191       0.867211         0.637654
# 24          0.498592       0.878904         0.636248
# 25          0.530500       0.789845         0.634702
# 26          0.524310       0.791126         0.630658
# 27          0.621588       0.638315         0.629840
# 28          0.517406       0.799936         0.628374
# 29          0.491935       0.859843         0.625823
# 30          0.625121       0.619414         0.622254
# 31          0.665154       0.516418         0.581425
# 32          0.429029       0.901009         0.581275
# 33          0.822422       0.293769         0.432905

# %% [markdown]
# ### Sort by Recall

# %%
pd.concat([summary_df, summary_df_ensemble]).sort_values(by='Recall(toxic)', ascending=False).reset_index()
# Out:
#     index Text Vectorization Classification Algorithm    Resampling Technique  \
# 0      12           'TF-IDF'                   'LGBM'                    None
# 1       3           'TF-IDF'    'Logistic Regression'                 'SMOTE'
# 2       4           'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 3       3           'TF-IDF'                'XGBoost'                    None
# 4       2           'TF-IDF'    'Logistic Regression'    'Random Oversampler'
# 5       7  'CountVectorizer'    'Logistic Regression'    'Random Oversampler'
# 6       5           'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 7       6           'TF-IDF'                'XGBoost'                    None
# 8       8  'CountVectorizer'    'Logistic Regression'                 'SMOTE'
# 9      15           'TF-IDF'         'Random Forests'    'Random Oversampler'
# 10      1           'TF-IDF'    'Logistic Regression'                  'None'
# 11      0           'TF-IDF'    'Logistic Regression'                  'None'
# 12     14           'TF-IDF'         'Random Forests'                    None
# 13     15           'TF-IDF'                   'LGBM'                    None
# 14     14           'TF-IDF'                   'LGBM'                    None
# 15     16           'TF-IDF'                   'LGBM'                    None
# 16     11           'TF-IDF'            'Naive Bayes'                 'SMOTE'
# 17     13           'TF-IDF'            'Naive Bayes'             'Near Miss'
# 18     13           'TF-IDF'                   'LGBM'                    None
# 19     10           'TF-IDF'                   'LGBM'                    None
# 20     10           'TF-IDF'            'Naive Bayes'    'Random Oversampler'
# 21     12           'TF-IDF'            'Naive Bayes'   'Random Undersampler'
# 22     17           'TF-IDF'                   'LGBM'                    None
# 23      7           'TF-IDF'                   'LGBM'                    None
# 24      8           'TF-IDF'                   'LGBM'                    None
# 25      9           'TF-IDF'                   'LGBM'                    None
# 26      4           'TF-IDF'                'XGBoost'                    None
# 27     11  'CountVectorizer'                   'LGBM'                    None
# 28      2           'TF-IDF'                'XGBoost'                    None
# 29      1           'TF-IDF'         'Random Forests'                    None
# 30      6  'CountVectorizer'    'Logistic Regression'                  'None'
# 31      9           'TF-IDF'            'Naive Bayes'                  'None'
# 32      5           'TF-IDF'                'XGBoost'                    None
# 33      0           'TF-IDF'         'Random Forests'                    None
#
#     Precision(non-toxic)  Recall(non-toxic)  f1-Score(non-toxic)  \
# 0               0.987745           0.869350             0.924774
# 1               0.985625           0.904656             0.943407
# 2               0.985610           0.903696             0.942877
# 3               0.984300           0.907082             0.944115
# 4               0.983619           0.910660             0.945734
# 5               0.983374           0.903243             0.941607
# 6               0.983206           0.912423             0.946493
# 7               0.978949           0.930940             0.954341
# 8               0.978508           0.921725             0.949268
# 9               0.978202           0.928881             0.952904
# 10              0.978287           0.934151             0.955710
# 11              0.978239           0.933628             0.955413
# 12              0.977909           0.934814             0.955876
# 13              0.977830           0.936036             0.956477
# 14              0.977795           0.936822             0.956870
# 15              0.977561           0.937485             0.957104
# 16              0.976823           0.918706             0.946873
# 17              0.976859           0.923121             0.949230
# 18              0.977081           0.938968             0.957645
# 19              0.976693           0.935425             0.955614
# 20              0.975906           0.921795             0.948079
# 21              0.975814           0.923837             0.949114
# 22              0.975295           0.941150             0.957918
# 23              0.973330           0.944588             0.958744
# 24              0.973239           0.944466             0.958637
# 25              0.972424           0.940399             0.956144
# 26              0.972466           0.943104             0.957560
# 27              0.970517           0.945059             0.957619
# 28              0.970108           0.950417             0.960162
# 29              0.960476           0.957660             0.959066
# 30              0.958574           0.959527             0.959050
# 31              0.957021           0.971936             0.964421
# 32              0.948564           0.971674             0.959980
# 33              0.928088           0.993089             0.959489
#
#     Precision(toxic)  Recall(toxic)  f1-Score(toxic)
# 0           0.429029       0.901009         0.581275
# 1           0.501096       0.878904         0.638283
# 2           0.498592       0.878904         0.636248
# 3           0.504191       0.867211         0.637654
# 4           0.512151       0.860804         0.642208
# 5           0.491935       0.859843         0.625823
# 6           0.516011       0.856960         0.644151
# 7           0.562907       0.816274         0.666318
# 8           0.531250       0.814192         0.642970
# 9           0.553767       0.810027         0.657821
# 10          0.572610       0.809707         0.670825
# 11          0.570574       0.809387         0.669316
# 12          0.574019       0.806183         0.670575
# 13          0.578348       0.805222         0.673184
# 14          0.581212       0.804741         0.674951
# 15          0.583101       0.802499         0.675430
# 16          0.517406       0.799936         0.628374
# 17          0.531134       0.799295         0.638189
# 18          0.587521       0.797854         0.676720
# 19          0.572946       0.795131         0.665996
# 20          0.524310       0.791126         0.630658
# 21          0.530500       0.789845         0.634702
# 22          0.591223       0.781195         0.673061
# 23          0.599874       0.762454         0.671463
# 24          0.599093       0.761653         0.670663
# 25          0.579951       0.755246         0.656091
# 26          0.591120       0.754926         0.663056
# 27          0.593597       0.736505         0.657374
# 28          0.616392       0.731219         0.668913
# 29          0.621588       0.638315         0.629840
# 30          0.625121       0.619414         0.622254
# 31          0.699439       0.599391         0.645562
# 32          0.665154       0.516418         0.581425
# 33          0.822422       0.293769         0.432905

# %% [markdown]
# ## Sort by Precision

# %%
pd.concat([summary_df, summary_df_ensemble]).sort_values(by='Precision(toxic)', ascending=False).reset_index()
# Out:
#     index Text Vectorization Classification Algorithm    Resampling Technique  \
# 0       0           'TF-IDF'         'Random Forests'                    None
# 1       9           'TF-IDF'            'Naive Bayes'                  'None'
# 2       5           'TF-IDF'                'XGBoost'                    None
# 3       6  'CountVectorizer'    'Logistic Regression'                  'None'
# 4       1           'TF-IDF'         'Random Forests'                    None
# 5       2           'TF-IDF'                'XGBoost'                    None
# 6       7           'TF-IDF'                   'LGBM'                    None
# 7       8           'TF-IDF'                   'LGBM'                    None
# 8      11  'CountVectorizer'                   'LGBM'                    None
# 9      17           'TF-IDF'                   'LGBM'                    None
# 10      4           'TF-IDF'                'XGBoost'                    None
# 11     13           'TF-IDF'                   'LGBM'                    None
# 12     16           'TF-IDF'                   'LGBM'                    None
# 13     14           'TF-IDF'                   'LGBM'                    None
# 14      9           'TF-IDF'                   'LGBM'                    None
# 15     15           'TF-IDF'                   'LGBM'                    None
# 16     14           'TF-IDF'         'Random Forests'                    None
# 17     10           'TF-IDF'                   'LGBM'                    None
# 18      1           'TF-IDF'    'Logistic Regression'                  'None'
# 19      0           'TF-IDF'    'Logistic Regression'                  'None'
# 20      6           'TF-IDF'                'XGBoost'                    None
# 21     15           'TF-IDF'         'Random Forests'    'Random Oversampler'
# 22      8  'CountVectorizer'    'Logistic Regression'                 'SMOTE'
# 23     13           'TF-IDF'            'Naive Bayes'             'Near Miss'
# 24     12           'TF-IDF'            'Naive Bayes'   'Random Undersampler'
# 25     10           'TF-IDF'            'Naive Bayes'    'Random Oversampler'
# 26     11           'TF-IDF'            'Naive Bayes'                 'SMOTE'
# 27      5           'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 28      2           'TF-IDF'    'Logistic Regression'    'Random Oversampler'
# 29      3           'TF-IDF'                'XGBoost'                    None
# 30      3           'TF-IDF'    'Logistic Regression'                 'SMOTE'
# 31      4           'TF-IDF'    'Logistic Regression'   'Random Undersampler'
# 32      7  'CountVectorizer'    'Logistic Regression'    'Random Oversampler'
# 33     12           'TF-IDF'                   'LGBM'                    None
#
#     Precision(non-toxic)  Recall(non-toxic)  f1-Score(non-toxic)  \
# 0               0.928088           0.993089             0.959489
# 1               0.957021           0.971936             0.964421
# 2               0.948564           0.971674             0.959980
# 3               0.958574           0.959527             0.959050
# 4               0.960476           0.957660             0.959066
# 5               0.970108           0.950417             0.960162
# 6               0.973330           0.944588             0.958744
# 7               0.973239           0.944466             0.958637
# 8               0.970517           0.945059             0.957619
# 9               0.975295           0.941150             0.957918
# 10              0.972466           0.943104             0.957560
# 11              0.977081           0.938968             0.957645
# 12              0.977561           0.937485             0.957104
# 13              0.977795           0.936822             0.956870
# 14              0.972424           0.940399             0.956144
# 15              0.977830           0.936036             0.956477
# 16              0.977909           0.934814             0.955876
# 17              0.976693           0.935425             0.955614
# 18              0.978287           0.934151             0.955710
# 19              0.978239           0.933628             0.955413
# 20              0.978949           0.930940             0.954341
# 21              0.978202           0.928881             0.952904
# 22              0.978508           0.921725             0.949268
# 23              0.976859           0.923121             0.949230
# 24              0.975814           0.923837             0.949114
# 25              0.975906           0.921795             0.948079
# 26              0.976823           0.918706             0.946873
# 27              0.983206           0.912423             0.946493
# 28              0.983619           0.910660             0.945734
# 29              0.984300           0.907082             0.944115
# 30              0.985625           0.904656             0.943407
# 31              0.985610           0.903696             0.942877
# 32              0.983374           0.903243             0.941607
# 33              0.987745           0.869350             0.924774
#
#     Precision(toxic)  Recall(toxic)  f1-Score(toxic)
# 0           0.822422       0.293769         0.432905
# 1           0.699439       0.599391         0.645562
# 2           0.665154       0.516418         0.581425
# 3           0.625121       0.619414         0.622254
# 4           0.621588       0.638315         0.629840
# 5           0.616392       0.731219         0.668913
# 6           0.599874       0.762454         0.671463
# 7           0.599093       0.761653         0.670663
# 8           0.593597       0.736505         0.657374
# 9           0.591223       0.781195         0.673061
# 10          0.591120       0.754926         0.663056
# 11          0.587521       0.797854         0.676720
# 12          0.583101       0.802499         0.675430
# 13          0.581212       0.804741         0.674951
# 14          0.579951       0.755246         0.656091
# 15          0.578348       0.805222         0.673184
# 16          0.574019       0.806183         0.670575
# 17          0.572946       0.795131         0.665996
# 18          0.572610       0.809707         0.670825
# 19          0.570574       0.809387         0.669316
# 20          0.562907       0.816274         0.666318
# 21          0.553767       0.810027         0.657821
# 22          0.531250       0.814192         0.642970
# 23          0.531134       0.799295         0.638189
# 24          0.530500       0.789845         0.634702
# 25          0.524310       0.791126         0.630658
# 26          0.517406       0.799936         0.628374
# 27          0.516011       0.856960         0.644151
# 28          0.512151       0.860804         0.642208
# 29          0.504191       0.867211         0.637654
# 30          0.501096       0.878904         0.638283
# 31          0.498592       0.878904         0.636248
# 32          0.491935       0.859843         0.625823
# 33          0.429029       0.901009         0.581275
