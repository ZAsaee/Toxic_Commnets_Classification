# %% [markdown]
# # Modeling - Classification Algorithms

# %% [markdown]
# ## Table of Contents:
# [1. Import Train and Test Set](#1.-Import-Train-and-Test-Set)
# <br>[2. Performance Evaluation Functions](#2.-Performance-Evaluation-Functions)
# <br>&emsp;&emsp;&emsp;[2.1. ROC Curve](#2.1.-ROC-Curve)
# <br>&emsp;&emsp;&emsp;[2.2. Precision/Recall Curve](#2.2.-Precision/Recall-Curve)
# <br>&emsp;&emsp;&emsp;[2.3. Test the functions](#2.3.-Test-the-functions)
# <br>[3. Classification and HyperParameter Tuning Function](#3.-Classification-and-HyperParameter-Tuning-Function)
# <br>[4. Classifiers](#4.-Classifiers)
# <br>&emsp;&emsp;&emsp;[4.1. Logistic Regression](#4.1.-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.1.1. TF-IDF and Logistic Regression](#4.1.1.-TF-IDF-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.1.2. TF-IDF, Random Oversampling and Logistic Regression](#4.1.2.-TF-IDF,-Random-Oversampling-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.1.3. TF-IDF, SMOTE Oversampling and Logistic Regression](#4.1.3.-TF-IDF,-SMOTE-Oversampling-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.1.4. TF-IDF, Random Undersampling and Logistic Regression](#4.1.4.-TF-IDF,-Random-Undersampling-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.1.5. TF-IDF, NearMiss Undersampling and Logistic Regression](#4.1.5.-TF-IDF,-NearMiss-Undersampling-and-Logistic-Regression)
# <br>&emsp;&emsp;&emsp;[4.2. Random Forest](#4.2.-Random-Forest)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.2.1. TF-IDF and Random Forest](#4.2.1.-TF-IDF-and-Random-Forest)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.2.2. TF-IDF, Random Over Sampling and Random Forest](#4.2.2.-TFIDF,-Random-Over-Sampling-and-Random-Forest)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.2.3. TF-IDF, SMOTE Over Sampling and Random Forest](#4.2.3.-TFIDF,-SMOTE-Over-Sampling-and-Random-Forest)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.2.4. TF-IDF, Random Under Sampling and Random Forest](#4.2.4.-TFIDF,-Random-Under-Sampling-and-Random-Forest)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.2.5. TF-IDF, NearMiss Under Sampling and Random Forest](#4.2.5.-TFIDF,-NearMiss-Under-Sampling-and-Random-Forest)
# <br>&emsp;&emsp;&emsp;[4.3. Naive Bayes](#4.3.-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.3.1. TF-IDF and Naive Bayes](#4.3.1.-Tf-Idf-and-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.3.2. TF-IDF, Random Over Sampling and Naive Bayes](#4.3.2.-Tf-Idf,-Random-Over-Sampling-and-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.3.3. TF-IDF, SMOTE Over Sampling and Naive Bayes](#4.3.3.-Tf-Idf,-SMOTE-Over-Sampling-and-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.3.4. TF-IDF, Random Under Sampling and Naive Bayes](#4.3.4.-Tf-Idf,-Random-Under-Sampling-and-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.3.5. TF-IDF, NearMiss Under Sampling and Naive Bayes](#4.3.5.-Tf-Idf,-NearMiss-Under-Sampling-and-Naive-Bayes)
# <br>&emsp;&emsp;&emsp;[4.4. Summary](#4.4.-Summary)

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
from sklearn.utils.fixes import loguniform
from itertools import cycle
from timeit import default_timer as timer

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
# from lightgbm import LGBMClassifier
from sklearn import naive_bayes
from sklearn.neighbors import KNeighborsClassifier

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.pipeline import Pipeline

from sklearn.metrics import classification_report
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import RocCurveDisplay


from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.metrics import precision_recall_fscore_support

from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import NearMiss
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek

from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

from Bayes_Opt_Classification import bayes_kfold_pipeline

# %% [markdown]
# ## 1. Import Train and Test Set

# %%
df = pd.read_csv('Library/cleaned_text_train_df.csv')
df.head()
# Out:
#                                           clean_text  toxic_type
# 0  explanation edit make username hardcore metall...           0
# 1  aww match background colour seemingly stuck th...           0
# 2  hey man really not try edit war guy constantly...           0
# 3  make real suggestion improvement wonder sectio...           0
# 4                      sir hero chance remember page           0

# %%
df.isna().sum()
# Out:
# clean_text    54
# toxic_type     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df_test = pd.read_csv('Library/cleaned_text_test_df.csv')
df_test.head()
# Out:
#                                           clean_text  toxic_type
# 0  thank understand think highly would not revert...           0
# 1                             dear god site horrible           0
# 2  somebody invariably try add religion really me...           0
# 3  say right type type institution need case thre...           0
# 4  add new product list make sure relevant add ne...           0

# %%
df_test.isna().sum()
# Out:
# clean_text    437
# toxic_type      0
# dtype: int64

# %%
df_test = df_test.dropna()

# %%
df_test.head()
# Out:
#                                           clean_text  toxic_type
# 0  thank understand think highly would not revert...           0
# 1                             dear god site horrible           0
# 2  somebody invariably try add religion really me...           0
# 3  say right type type institution need case thre...           0
# 4  add new product list make sure relevant add ne...           0

# %%
X_train = df['clean_text']
y_train = df['toxic_type']

X_test = df_test['clean_text']
y_test = df_test['toxic_type']

summary_dic ={}

# %% [markdown]
# ## 2. Classifiers

# %% [markdown]
# ### 2.1. Logistic Regression

# %% [markdown]
# ### 2.1.1. TF-IDF and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
#     'clf__dual': (True, False),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = None

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'None'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR1'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 406 seconds elapsed.
# total iterations will be taken to explore all subspaces:  100
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 11.543374964476037
# 	tfidf__max_features: 21599
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99    143292
#            1       0.94      0.81      0.87     16225
#
#     accuracy                           0.98    159517
#    macro avg       0.96      0.90      0.93    159517
# weighted avg       0.97      0.98      0.97    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96     57298
#            1       0.57      0.81      0.67      6243
#
#     accuracy                           0.92     63541
#    macro avg       0.78      0.87      0.81     63541
# weighted avg       0.94      0.92      0.93     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR1'].append('LR1')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR1']))
f.close()

# %% [markdown]
# ### 2.1.2. TF-IDF, Random Oversampler and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
    'over__sampling_strategy': (0.3, 1),
#     'over__shrinkage': Real(0,0.9),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('over', RandomOverSampler())

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Oversampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR2'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 433 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 2.3272425238241765
# 	over__sampling_strategy: 0.3
# 	tfidf__max_features: 30000
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98    143292
#            1       0.86      0.86      0.86     16225
#
#     accuracy                           0.97    159517
#    macro avg       0.92      0.92      0.92    159517
# weighted avg       0.97      0.97      0.97    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.95     57298
#            1       0.52      0.86      0.65      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.89      0.80     63541
# weighted avg       0.94      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR2'].append('LR2')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR2']))
f.close()

# %% [markdown]
# ### 2.1.3. TF-IDF, SMOTE Oversampling and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
    'over__sampling_strategy': (0.3, 1),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('over', SMOTE())

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'SMOTE'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR3'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 758 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 1.136085999295069
# 	over__sampling_strategy: 0.3
# 	tfidf__max_features: 30000
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98    143292
#            1       0.84      0.82      0.83     16225
#
#     accuracy                           0.97    159517
#    macro avg       0.91      0.90      0.90    159517
# weighted avg       0.96      0.97      0.97    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94     57298
#            1       0.50      0.88      0.64      6243
#
#     accuracy                           0.90     63541
#    macro avg       0.74      0.89      0.79     63541
# weighted avg       0.94      0.90      0.91     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR3'].append('LR3')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR3']))
f.close()

# %% [markdown]
# ### 2.1.4. TF-IDF, Random Undersampler and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
    'under__sampling_strategy': (0.3, 1),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('under', RandomUnderSampler())

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Undersampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR4'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 360 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 2.00903168991931
# 	tfidf__max_features: 19911
# 	under__sampling_strategy: 0.3302071990576378
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98    143292
#            1       0.83      0.82      0.83     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.90      0.90      0.90    159517
# weighted avg       0.96      0.96      0.96    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.95     57298
#            1       0.51      0.87      0.64      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.89      0.79     63541
# weighted avg       0.94      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR4'].append('LR4')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR4']))
f.close()

# %% [markdown]
# ### 2.1.5. TF-IDF, NearMiss Undersampler and Logistic Regression

# %%
parameters = {
    'tfidf__max_features': (1000, 30000),
    'under__sampling_strategy': (0.3, 1),
    'under__n_neighbors': (3,10),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('under', NearMiss())

classifier_name = 'Logistic Regression'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Undersampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR5'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 2857 seconds elapsed.
# total iterations will be taken to explore all subspaces:  200
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 5.082430978008421
# 	tfidf__max_features: 30000
# 	under__n_neighbors: 10
# 	under__sampling_strategy: 0.3
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98    143292
#            1       0.86      0.85      0.86     16225
#
#     accuracy                           0.97    159517
#    macro avg       0.92      0.92      0.92    159517
# weighted avg       0.97      0.97      0.97    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.95     57298
#            1       0.52      0.86      0.65      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.75      0.89      0.80     63541
# weighted avg       0.94      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR5'].append('LR5')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR5']))
f.close()

# %% [markdown]
# ### 2.1.6. Countvectorizer and Logistic Regression

# %%
parameters = {
    'count__max_features': (1000, 30000),
#     'clf__dual': (True, False),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('count', CountVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = None

classifier_name = 'Logistic Regression'
text_vec_name = 'CountVectorizer'
resample_method_name = 'None'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR6'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 637 seconds elapsed.
# total iterations will be taken to explore all subspaces:  100
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 4.39478075732859
# 	count__max_features: 30000
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97    143292
#            1       0.92      0.60      0.72     16225
#
#     accuracy                           0.95    159517
#    macro avg       0.94      0.80      0.85    159517
# weighted avg       0.95      0.95      0.95    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     57298
#            1       0.62      0.63      0.63      6243
#
#     accuracy                           0.93     63541
#    macro avg       0.79      0.79      0.79     63541
# weighted avg       0.93      0.93      0.93     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR6'].append('LR6')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR6']))
f.close()

# %% [markdown]
# ### 2.1.7. Countvectorizer, Random Oversampler and Logistic Regression

# %%
parameters = {
    'count__max_features': (1000, 30000),
    'over__sampling_strategy': (0.3, 1),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('count', CountVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('over', RandomOverSampler())

classifier_name = 'Logistic Regression'
text_vec_name = 'CountVectorizer'
resample_method_name = 'Random Oversampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR7'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 924 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 6.720875847559373
# 	count__max_features: 23559
# 	over__sampling_strategy: 0.42457997761958555
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98    143292
#            1       0.81      0.81      0.81     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.89      0.89      0.89    159517
# weighted avg       0.96      0.96      0.96    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94     57298
#            1       0.50      0.84      0.63      6243
#
#     accuracy                           0.90     63541
#    macro avg       0.74      0.87      0.79     63541
# weighted avg       0.93      0.90      0.91     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR7'].append('LR7')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR7']))
f.close()

# %% [markdown]
# ### 2.1.8. Countvectorizer, SMOTE Oversampler and Logistic Regression

# %%
parameters = {
    'count__max_features': (1000, 30000),
    'over__sampling_strategy': (0.3, 1),
    'clf__C': (1e-5, 1e2, "log-uniform")
}

text_vec = ('count', CountVectorizer())
classifier = ('clf', LogisticRegression(solver='liblinear'))
resample = ('over', SMOTE())

classifier_name = 'Logistic Regression'
text_vec_name = 'CountVectorizer'
resample_method_name = 'SMOTE'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR8'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 1071 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__C: 3.844750848627325
# 	count__max_features: 30000
# 	over__sampling_strategy: 0.3
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    143292
#            1       0.84      0.73      0.78     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.90      0.86      0.88    159517
# weighted avg       0.96      0.96      0.96    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95     57298
#            1       0.54      0.80      0.65      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.76      0.87      0.80     63541
# weighted avg       0.93      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR8'].append('LR8')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR8']))
f.close()

# %% [markdown]
# ## 2.2. Naive Bayes

# %% [markdown]
# ### 2.2.1. TFIDF and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
#     'over__sampling_strategy': (0.3, 1),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = None

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'None'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR9'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 355 seconds elapsed.
# total iterations will be taken to explore all subspaces:  150
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	tfidf__max_features: 6475
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97    143292
#            1       0.94      0.55      0.70     16225
#
#     accuracy                           0.95    159517
#    macro avg       0.94      0.77      0.83    159517
# weighted avg       0.95      0.95      0.95    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     57298
#            1       0.70      0.60      0.65      6243
#
#     accuracy                           0.94     63541
#    macro avg       0.83      0.79      0.81     63541
# weighted avg       0.93      0.94      0.93     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR9'].append('LR9')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR9']))
f.close()

# %% [markdown]
# ### 2.2.2. TFIDF, Random Oversampler and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
    'over__sampling_strategy': (0.3, 1),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = ('over', RandomOverSampler())

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Oversampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR10'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 373 seconds elapsed.
# total iterations will be taken to explore all subspaces:  200
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	over__sampling_strategy: 0.3
# 	tfidf__max_features: 13202
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    143292
#            1       0.80      0.76      0.78     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.89      0.87      0.88    159517
# weighted avg       0.96      0.96      0.96    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     57298
#            1       0.54      0.78      0.64      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.76      0.85      0.79     63541
# weighted avg       0.93      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR10'].append('LR10')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR10']))
f.close()

# %% [markdown]
# ### 2.2.3. TFIDF, SMOTE and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
    'over__sampling_strategy': (0.3, 1),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = ('over', SMOTE())

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'SMOTE'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR11'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 694 seconds elapsed.
# total iterations will be taken to explore all subspaces:  200
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	over__sampling_strategy: 0.3236671608347572
# 	tfidf__max_features: 13614
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    143292
#            1       0.80      0.75      0.78     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.89      0.87      0.88    159517
# weighted avg       0.96      0.96      0.96    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95     57298
#            1       0.54      0.78      0.64      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.76      0.86      0.79     63541
# weighted avg       0.93      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR11'].append('LR11')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR11']))
f.close()

# %% [markdown]
# ### 2.2.4. TFIDF, Random Undersampler and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
    'under__sampling_strategy': (0.3, 1),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = ('under', RandomUnderSampler())

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'Random Undersampler'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR12'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 351 seconds elapsed.
# total iterations will be taken to explore all subspaces:  200
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	tfidf__max_features: 9052
# 	under__sampling_strategy: 0.3
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    143292
#            1       0.81      0.73      0.77     16225
#
#     accuracy                           0.96    159517
#    macro avg       0.89      0.86      0.87    159517
# weighted avg       0.95      0.96      0.95    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95     57298
#            1       0.54      0.78      0.64      6243
#
#     accuracy                           0.91     63541
#    macro avg       0.76      0.85      0.79     63541
# weighted avg       0.93      0.91      0.92     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR12'].append('LR12')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR12']))
f.close()

# %% [markdown]
# ### 2.1.5. TF-IDF, NearMiss Undersampler and Naive Bayes

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
    'under__sampling_strategy': (0.3, 1),
    'under__n_neighbors': (3,10),
    'clf__alpha': (1,10),
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', naive_bayes.MultinomialNB())
resample = ('under', NearMiss())

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'Near Miss'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR13'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 3026 seconds elapsed.
# total iterations will be taken to explore all subspaces:  250
# ------------------------------------------------------------------
#
#  Parameters of the best model:
# 	clf__alpha: 1
# 	clf__fit_prior: True
# 	tfidf__max_features: 7339
# 	under__n_neighbors: 10
# 	under__sampling_strategy: 0.4526820659021512
# ------------------------------------------------------------------
# Classification report for the train set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97    143292
#            1       0.73      0.78      0.75     16225
#
#     accuracy                           0.95    159517
#    macro avg       0.85      0.88      0.86    159517
# weighted avg       0.95      0.95      0.95    159517
#
# Classification report for the test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94     57298
#            1       0.48      0.84      0.61      6243
#
#     accuracy                           0.89     63541
#    macro avg       0.73      0.87      0.78     63541
# weighted avg       0.93      0.89      0.91     63541
#
# ------------------------------------------------------------------

# %%
summary_dic['LR13'].append('LR13')

f = open('summary_results', 'a')
f.write(repr(summary_dic['LR13']))
f.close()

# %%
from xgboost.sklearn import XGBClassifier

# %%
parameters = {
    'tfidf__max_features': (1000, 50000),
#     'under__sampling_strategy': (0.3, 1),
#     'under__n_neighbors': (3,10),
#     'clf__learning_rate': 0.1,
    'clf__fit_prior': (True, False)
}

text_vec = ('tfidf', TfidfVectorizer())
classifier = ('clf', XGBClassifier(learning_rate =0.1, n_estimators=1000, max_depth=5, min_child_weight=1,
 gamma=0,  subsample=0.8, colsample_bytree=0.8, objective= 'binary:logistic', nthread=4, scale_pos_weight=1,
 seed=27))
resample = None

classifier_name = 'Naive Bayes'
text_vec_name = 'TF-IDF'
resample_method_name = 'Near Miss'

categories = ['Non-Toxic', 'Toxic']

summary_dic['LR14'] = \
list(bayes_kfold_pipeline(X_train, X_test, y_train, y_test, text_vec=text_vec, scoring='f1', \
    classifier=classifier, parameters=parameters, cv_n_splits=5, bayes_n_iter=50,  classifier_name=classifier_name, \
    text_vec_name=text_vec_name, resample_method_name=resample_method_name, \
    categories=categories, n_classes=[0,1], verbose=1, n_jobs=5,  resample=resample))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
