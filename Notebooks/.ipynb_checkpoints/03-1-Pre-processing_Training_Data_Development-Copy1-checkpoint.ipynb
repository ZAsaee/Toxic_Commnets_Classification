# %% [markdown]
# #  Pre-processing & Training Data Development

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# [1. Introduction](#1.-Introduction)
# <br>[2. Import Libraries and Data](#2.-Import-Libraries-and-Data)
# <br>[3. Evaluate the Text Vectorization Algorithms](#3.-Evaluate-the-Text-Vectorization-Algorithms)
# <br>&emsp;&emsp;&emsp;[3.1. BOW Term Frequency](#3.1.-BOW-Term-Frequency)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.1. Initial Exploration](#3.1.1.-Initial-Exploration)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.2. BOW Term Frequency - Parameters Evaluation](#3.1.2.-BOW-Term-Frequency---Parameters-Evaluation)
# <br>&emsp;&emsp;&emsp;[3.2. Normalized TF-IDF](#3.2.-Normalized-TF-IDF)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.2.1. Initial Exploration](#3.2.1.-Initial-Exploration)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.2.2. TF-IDF Vectorization - Parameters Evaluation](#3.2.2.-TF-IDF-Vectorization---Parameters-Evaluation)
# <br>&emsp;&emsp;&emsp;[3.3. Summary of Text Vecorization](#3.3.-Summary-of-Text-Vecorization)
# <br>[4. Evaluate Imbalanced Algorithm](#4.-Evaluate-Imbalanced-Algorithm)
# <br>&emsp;&emsp;&emsp;[4.1. Oversampling Algorithms](#4.1.-Oversampling-Algorithms)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.1.1. Random Oversampling](#4.1.1.-Random-Oversampling)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.1.2. Synthetic Minority Oversampling Technique (SMOTE)](#4.1.2.-Synthetic-Minority-Oversampling-Technique-(SMOTE))
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.1.3. Adaptive Synthetic Sampling (ADASYN)](#4.1.3.-Adaptive-Synthetic-Sampling-(ADASYN))
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.1.4. Borderline SMOTE](#4.1.4.-Borderline-SMOTE)
# <br>&emsp;&emsp;&emsp;[4.2. Summary of Oversampling](#4.2.-Summary-of-Oversampling)
# <br>&emsp;&emsp;&emsp;[4.3. Undersampling Algorithms](#4.3.-Undersampling-Algorithms)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.3.1. Random Undersampling](#4.3.1.-Random-Undersampling)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.3.2. NearMiss](#4.3.2.-NearMiss)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.3.3. EditedNearestNeighbours](#4.3.3.-EditedNearestNeighbours)
# <br>&emsp;&emsp;&emsp;[4.4. Summary of Undersampling](#4.4.-Summary-of-Undersampling)
# <br>&emsp;&emsp;&emsp;[4.5. Combined Methods](#4.5.-Combined-Methods)
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[4.5.1. SMOTETomek](#4.5.1.-SMOTETomek)

# %% [markdown]
# ## 1. Introduction
#
# Classification predictive modelling is a category of machine learning problems where a class label is assigned to a given dataset. The main types of classification problems are binary classification, multi-class classification, multi-label classification and imbalanced classification. The present project is a binary imbalanced classification problem with the following labels. The labels are “toxic” and “non-toxic”. The distribution of comments in these two labels is not uniformly distributed, therefore it is an imbalanced classification.
#
#
# |  | <b>Label | <b>Number of Comments |
# | :- | :-: | :-: |
# |1| Non-toxic | 143346 |
# |2| Toxic | 16225 |
#
#    The imbalanced classification is a challenging problem. It requires a high-level framework for systematically handling the skewed class distribution. In this project, I follow the below systematic framework to evaluate various methods of classification:
#
# #### 1. Select a performance metric
#
# One of the main steps for the evaluation of the model is selecting the right metric. There are mainly two factors for the choice of classification: imbalanced or balanced dataset, and the business use-case to solve. In the case of imbalanced classification, selecting the appropriate metric is more challenging. Since most of the widely used standard metrics assume a balanced class distribution. For example, classification accuracy is one of the most common standard metrics for the classification problem. However, this metric for the imbalanced classification problem is very dangerous and misleading.
# There are four types of outcomes for the classification prediction: True Positive (TP), True Negative (TN), False Positive (FP), and False Negative (FN). Four performance metrics based on these outcomes are defined as follows:
#
#
# \begin{gather*}
# Accuray = \frac {TP + TN} {TP + FP + TN + FN}
# \end{gather*}
#
#
# \begin{gather*}
# Precision = \frac {TP} {TP + FP}
# \end{gather*}
#
#
# \begin{gather*}
# Recall = \frac {TP} {TP + FN}
# \end{gather*}
#
#
# \begin{gather*}
# F1 = \frac {2 * Precision * Recall} {Precision + Recall}
# \end{gather*}
#
# For binary imbalanced classification tasks, the majority class is normal (called the “negative class”), and the minority class is the exception (called the “positive class”). As mentioned earlier, the accuracy metric is not an appropriate choice for imbalanced classification problems. Based on the level of tolerance with respect to false positives and false negatives, the right performance metric can be selected.
# In the current study, the assumption is that a social media platform is willing to detect toxic comments and block the corresponding accounts. Therefore, it is essential to decrease false positives, since we don’t want to block an account by mistake (high precision). On the other hand, it is important to detect toxic comments and block them (high recall). In practice, we can’t achieve both high precision and high recall. An increase in precision metric reduces recall metric and vice versa. This is called the precision/recall tradeoff. Therefore, the F1 score is better metric performance when we are seeking a balance between precision and recall.
# Moreover, the receiver operator characteristic (ROC/AUC curve) is another useful metric for classification evaluation. For classification problems with probability outputs, a threshold can be used for the classification. ROC plots out the sensitivity and specificity for the different thresholds and possible outputs.
#
# \begin{gather*}
# Sensitivity = \frac {TP} {TP + FN}
# \end{gather*}
#
# \begin{gather*}
# Specifity = \frac {FP} {FP + TN}
# \end{gather*}
#
# In the current srudy, the performance metric to evaluate the models are F1 score and ROC/AUC.
#
# #### 2. Evaluate the text vectorization algorithms
#
# The text vectorization algorithms used in this project are as follows:
#  - Bag of Words (BOW) Term Frequency
#  - Normalized TF-IDF
#
# #### 3. Evaluate classification algorithms
# I evaluate the performance of various classification algoritms as follows:
#  - Logistic Regression
#  - Random Forest Classifier
#  - XGBOOST Classifier
#  - LGBM Classifier
#  - Naive Bayes
#  - KNN
#
# #### 4. Evaluate imbalanced algorithms
# The performance of various undersampling and oversampling methods are evaluated as follows:
#  - Random Oversampling
#  - Synthetic Minority Oversampling (SMOTE)
#  - Adaptive Synthetic Sampling (ADASYN)
#  - Borderline SMOTE
#  - Random Undersampling
#  - NearMiss
#  - Edited Nearest Neighbor
#
# #### 5. Hyperparameter tuning
# GridSearchCV and BayesSearchCV are applied to select the suitable hyperparameters.

# %% [markdown]
# ## 2. Import Libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# Model selection
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# Resampling techniques selection
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import KMeansSMOTE
from imblearn.over_sampling import SVMSMOTE

from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import ClusterCentroids
from imblearn.under_sampling import NearMiss
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.combine import SMOTETomek
from imblearn.combine import SMOTEENN

from imblearn.pipeline import Pipeline as imbpipeline


pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', 150)
pd.set_option('display.notebook_repr_html', True)

# %% [markdown]
# In the preceding notebook, text vectorization and resampling techniques are examined. The initial model are trained using Logistic Regression model. Two techniques of Countvectorizer and TF-IDF are employed to vectorize the text. Moreover, several undersampling and oversampling techniques and their combinations are examined.

# %%
df = pd.read_csv('Library/cleaned_text_train_df.csv')
df.head()
# Out:
#                                                                                                                                               clean_text  toxic_type
# 0  explanation edit make username hardcore metallica fan revert vandalisms closure gas vote new york dolls fac please remove template talk page since...           0
# 1                                                                                     aww match background colour seemingly stuck thank talk january utc           0
# 2                hey man really not try edit war guy constantly remove relevant information talk edit instead talk page seem care formatting actual info           0
# 3  make real suggestion improvement wonder section statistic later subsection type accident think reference may need tidy exact format ie date format...           0
# 4                                                                                                                          sir hero chance remember page           0

# %%
df.isna().sum()
# Out:
# clean_text    54
# toxic_type     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## 3. Evaluate the Text Vectorization Algorithms

# %% [markdown]
# The main goal is to investigate the text vectorization algorithms and find out the optimum parameters. Initially, the models are tested with the default values. Afterward, GridSearch technique is employed to investigate the effects of parameters on the model.
# First, I split the dataset to train/test set and then fit the text vectorization model on the training set. Afterwards, both train and test are transformed using this fit. It is important to perform the split first to avoid data leakage.

# %% [markdown]
# ### 3.1. BOW Term Frequency

# %% [markdown]
# ### 3.1.1. Initial Exploration

# %%
# Train/test split
X = df['clean_text']
y = df['toxic_type']

# %%
# Define function to perform train/test split and then fitting and transforming using Countvectorizer

def countvectorize(X, y, max_df=0.95, min_df=0.001, ngram_range=(1,1)):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                                stratify=y, random_state=1)
    
    vectorizer = CountVectorizer(max_df=max_df, min_df=min_df, ngram_range=(1,1))
    Dict_count = vectorizer.fit(X_train)
    
    X_train_vec = Dict_count.transform(X_train).toarray()
    X_test_vec = Dict_count.transform(X_test).toarray()
    
    X_train_df = pd.DataFrame(data=X_train_vec, columns=vectorizer.get_feature_names())
    X_test_df = pd.DataFrame(data=X_test_vec, columns=vectorizer.get_feature_names())
    
    y_train_df = y_train
    y_test_df = y_test
    
    print('Number of labels in the train set: \n', y_train.value_counts(normalize=True))
    print('-----------------------------------')
    print('Number of labels in the test set: \n', y_test.value_counts(normalize=True))
    print('-----------------------------------')
    
    X_train = np.array(X_train_df)
    X_test = np.array(X_test_df)
    y_train = np.array(y_train_df)
    y_test = np.array(y_test_df)
    
    print("X train type and shape: ", type(X_train), X_train.shape)
    print("y train type and shape: ", type(y_train), y_train.shape)
    
    print("X test type and shape: ", type(X_test), X_test.shape)
    print("y test type and shape: ", type(y_test), y_test.shape)
    print('-----------------------------------')
    
    
    return X_train, X_test, y_train, y_test

# %%
# BOW Word Frequency

X_train_bow, X_test_bow, y_train_bow, y_test_bow = countvectorize(X, y, max_df=0.95, min_df=0.001, ngram_range=(1,1))
# Out:
# Number of labels in the train set:
#  0    0.898286
# 1    0.101714
# Name: toxic_type, dtype: float64
# -----------------------------------
# Number of labels in the test set:
#  0    0.898289
# 1    0.101711
# Name: toxic_type, dtype: float64
# -----------------------------------
# X train type and shape:  <class 'numpy.ndarray'> (127613, 2958)
# y train type and shape:  <class 'numpy.ndarray'> (127613,)
# X test type and shape:  <class 'numpy.ndarray'> (31904, 2958)
# y test type and shape:  <class 'numpy.ndarray'> (31904,)
# -----------------------------------

# %%
# Logistic Regression model

clf = LogisticRegression(solver='lbfgs', max_iter=20000, random_state=1)
clf_model = clf.fit(X_train_bow, y_train_bow)

y_pred_train_bow = clf_model.predict(X_train_bow)

y_pred_test_bow = clf_model.predict(X_test_bow)

# %% [markdown]
# I check the classification report for both train and test sets to check underfitting or overfitting of the model.

# %%
# Check the classification metrics for the test set

print("Test Classification Report")
print(classification_report(y_test_bow, y_pred_test_bow))
# Out:
# Test Classification Report
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     28659
#            1       0.86      0.64      0.74      3245
#
#     accuracy                           0.95     31904
#    macro avg       0.91      0.82      0.86     31904
# weighted avg       0.95      0.95      0.95     31904

# %%
# Check the classification metrics for the train set

print("Test Classification Report")
print(classification_report(y_train_bow, y_pred_train_bow))
# Out:
# Test Classification Report
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98    114633
#            1       0.91      0.66      0.76     12980
#
#     accuracy                           0.96    127613
#    macro avg       0.93      0.83      0.87    127613
# weighted avg       0.96      0.96      0.96    127613

# %% [markdown]
# As mentioned earlier, the classification metric for this study is f1-score; however, I keep checking precision and recall, as well.
#
# In terms of minority group (toxic comments), the initial model has a higher precision than recall. It was expected!
# The goal is to improve recall and thus f1-score.
#
# In the next section, I investiagte the effects of parameters on the output of BOW model.

# %% [markdown]
# ### 3.1.2. BOW Term Frequency - Parameters Evaluation

# %%
X = df['clean_text']
y = df['toxic_type']

#train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, random_state=1)

# %%
# Define the BOW and Logistic Regression models with different parameters

pipeline = Pipeline([('countvect', CountVectorizer()),
                     ('clf', LogisticRegression(solver='lbfgs', max_iter=20000))])

parameters = {
    'countvect__max_df': (0.95, 0.9, 0.85, 0.8),
    'countvect__min_df': (0.0001, 0.0005, 0.001, 0.002),
    'countvect__ngram_range': ((1,1), (2,2))
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, scoring='f1')
model_bow = grid_search.fit(X_train, y_train)

# %%
# Rank all models based on the f1-score metric

model_bow_results = pd.DataFrame(model_bow.cv_results_).sort_values(by='mean_test_score', ascending=False)
model_bow_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       10.432982      1.866859         0.662657        0.068872
# 8        9.090825      1.215975         0.566545        0.005077
# 24       8.839809      1.022437         0.558752        0.007119
# 16       8.854013      1.047872         0.566128        0.007749
# 18       8.173404      1.001998         0.549761        0.009949
# 26       8.149528      1.013364         0.542664        0.008855
# 2        8.699656      1.057683         0.618047        0.009326
# 10       8.169474      1.032815         0.554974        0.006630
# 12       7.220552      1.042784         0.546806        0.009530
# 28       7.159653      1.030859         0.537663        0.008782
# 20       7.181622      1.009740         0.536921        0.011758
# 4        8.027201      1.151801         0.621795        0.006342
# 22       6.691958      0.885304         0.525314        0.015363
# 14       6.691072      0.874775         0.531409        0.001909
# 30       6.691791      0.731539         0.543389        0.012296
# 6        6.744992      0.865440         0.529615        0.005578
# 1        8.724845      0.351676         0.942195        0.013466
# 17       7.983344      0.402603         0.857127        0.010479
# 9        8.045657      0.344047         0.863838        0.016539
# 25       7.975618      0.291010         0.847991        0.017757
# 3        7.184012      0.153570         0.904768        0.012956
# 27       6.430287      0.144647         0.793471        0.016718
# 11       6.488005      0.163254         0.804580        0.010491
# 19       6.478919      0.159535         0.812701        0.021175
# 13       6.277324      0.097248         0.792323        0.012496
# 21       6.217672      0.066639         0.790604        0.011824
# 5        6.973803      0.109072         0.892781        0.020018
# 29       6.210106      0.043877         0.782082        0.015400
# 23       6.095508      0.088096         0.776479        0.013298
# 7        6.116178      0.107104         0.779601        0.009215
# 15       6.154454      0.111620         0.777169        0.011570
# 31       6.107284      0.101653         0.783854        0.012008
#
#    param_countvect__max_df param_countvect__min_df  \
# 0                     0.95                  0.0001
# 8                      0.9                  0.0001
# 24                     0.8                  0.0001
# 16                    0.85                  0.0001
# 18                    0.85                  0.0005
# 26                     0.8                  0.0005
# 2                     0.95                  0.0005
# 10                     0.9                  0.0005
# 12                     0.9                   0.001
# 28                     0.8                   0.001
# 20                    0.85                   0.001
# 4                     0.95                   0.001
# 22                    0.85                   0.002
# 14                     0.9                   0.002
# 30                     0.8                   0.002
# 6                     0.95                   0.002
# 1                     0.95                  0.0001
# 17                    0.85                  0.0001
# 9                      0.9                  0.0001
# 25                     0.8                  0.0001
# 3                     0.95                  0.0005
# 27                     0.8                  0.0005
# 11                     0.9                  0.0005
# 19                    0.85                  0.0005
# 13                     0.9                   0.001
# 21                    0.85                   0.001
# 5                     0.95                   0.001
# 29                     0.8                   0.001
# 23                    0.85                   0.002
# 7                     0.95                   0.002
# 15                     0.9                   0.002
# 31                     0.8                   0.002
#
#    param_countvect__ngram_range  \
# 0                        (1, 1)
# 8                        (1, 1)
# 24                       (1, 1)
# 16                       (1, 1)
# 18                       (1, 1)
# 26                       (1, 1)
# 2                        (1, 1)
# 10                       (1, 1)
# 12                       (1, 1)
# 28                       (1, 1)
# 20                       (1, 1)
# 4                        (1, 1)
# 22                       (1, 1)
# 14                       (1, 1)
# 30                       (1, 1)
# 6                        (1, 1)
# 1                        (2, 2)
# 17                       (2, 2)
# 9                        (2, 2)
# 25                       (2, 2)
# 3                        (2, 2)
# 27                       (2, 2)
# 11                       (2, 2)
# 19                       (2, 2)
# 13                       (2, 2)
# 21                       (2, 2)
# 5                        (2, 2)
# 29                       (2, 2)
# 23                       (2, 2)
# 7                        (2, 2)
# 15                       (2, 2)
# 31                       (2, 2)
#
#                                                params  split0_test_score  \
# 0   {'countvect__max_df': 0.95, 'countvect__min_df...           0.750159
# 8   {'countvect__max_df': 0.9, 'countvect__min_df'...           0.750159
# 24  {'countvect__max_df': 0.8, 'countvect__min_df'...           0.750159
# 16  {'countvect__max_df': 0.85, 'countvect__min_df...           0.750159
# 18  {'countvect__max_df': 0.85, 'countvect__min_df...           0.737915
# 26  {'countvect__max_df': 0.8, 'countvect__min_df'...           0.737915
# 2   {'countvect__max_df': 0.95, 'countvect__min_df...           0.737915
# 10  {'countvect__max_df': 0.9, 'countvect__min_df'...           0.737915
# 12  {'countvect__max_df': 0.9, 'countvect__min_df'...           0.724054
# 28  {'countvect__max_df': 0.8, 'countvect__min_df'...           0.724054
# 20  {'countvect__max_df': 0.85, 'countvect__min_df...           0.724054
# 4   {'countvect__max_df': 0.95, 'countvect__min_df...           0.724054
# 22  {'countvect__max_df': 0.85, 'countvect__min_df...           0.689577
# 14  {'countvect__max_df': 0.9, 'countvect__min_df'...           0.689577
# 30  {'countvect__max_df': 0.8, 'countvect__min_df'...           0.689577
# 6   {'countvect__max_df': 0.95, 'countvect__min_df...           0.689577
# 1   {'countvect__max_df': 0.95, 'countvect__min_df...           0.350339
# 17  {'countvect__max_df': 0.85, 'countvect__min_df...           0.350339
# 9   {'countvect__max_df': 0.9, 'countvect__min_df'...           0.350339
# 25  {'countvect__max_df': 0.8, 'countvect__min_df'...           0
# 13           0.110553         0.100812        0.007282               25
# 21           0.110553         0.100812        0.007282               25
# 5            0.110553         0.100812        0.007282               25
# 29           0.110553         0.100812        0.007282               25
# 23           0.072982         0.063175        0.017317               29
# 7            0.072982         0.063175        0.017317               29
# 15           0.072982         0.063175        0.017317               29
# 31           0.072982         0.063175        0.017317               29

# %%
# Best model based on f1-score metric

print(model_bow.best_estimator_.steps)
# Out:
# [('countvect', CountVectorizer(max_df=0.95, min_df=0.0001)), ('clf', LogisticRegression(max_iter=20000))]

# %%
# Check the classification metrics for the test set

y_pred_bow = model_bow.predict(X_test)
print(classification_report(y_test, y_pred_bow))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     28659
#            1       0.85      0.70      0.77      3245
#
#     accuracy                           0.96     31904
#    macro avg       0.91      0.84      0.87     31904
# weighted avg       0.95      0.96      0.95     31904

# %%
# Check the classification metrics for the test set

y_pred_train_bow = model_bow.predict(X_train)
print(classification_report(y_train, y_pred_train_bow))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98    114633
#            1       0.95      0.76      0.84     12980
#
#     accuracy                           0.97    127613
#    macro avg       0.96      0.88      0.91    127613
# weighted avg       0.97      0.97      0.97    127613

# %%
# Summary of the results including fit time and score

bow = model_bow_results[['mean_fit_time', 'mean_score_time', 'params', 'mean_test_score']].head(1).transpose()
bow
# Out:
#                                                                  0
# mean_fit_time                                            10.432982
# mean_score_time                                           0.662657
# params           {'countvect__max_df': 0.95, 'countvect__min_df...
# mean_test_score                                           0.756486

# %% [markdown]
# ### 3.2. Normalized TF-IDF

# %% [markdown]
# The next text vectorization model that I use in this project is TF-IDF algorithm.

# %% [markdown]
# ### 3.2.1. Initial Exploration

# %%
# Train/test split
X = df['clean_text']
y = df['toxic_type']

# %%
# Define function to perform train/test split and then fitting and transforming using TF-IDF

def tfidfvectorize(X, y, max_df=0.95, min_df=0.001, ngram_range=(1,1), norm='l2', 
                   use_idf=True, smooth_idf=True, sublinear_tf=False):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                                stratify=y, random_state=1)
    
    vectorizer = TfidfVectorizer(max_df=0.95, min_df=0.001, ngram_range=(1,1), norm='l2', 
                   use_idf=True, smooth_idf=True, sublinear_tf=False)
    
    Dict_count = vectorizer.fit(X_train)
    
    X_train_vec = Dict_count.transform(X_train).toarray()
    X_test_vec = Dict_count.transform(X_test).toarray()
    
    X_train_df = pd.DataFrame(data=X_train_vec, columns=vectorizer.get_feature_names())
    X_test_df = pd.DataFrame(data=X_test_vec, columns=vectorizer.get_feature_names())
    
    y_train_df = y_train
    y_test_df = y_test
    
    print('Number of labels in the train set: \n', y_train.value_counts(normalize=True))
    print('-----------------------------------')
    print('Number of labels in the test set: \n', y_test.value_counts(normalize=True))
    print('-----------------------------------')
    
    X_train = np.array(X_train_df)
    X_test = np.array(X_test_df)
    y_train = np.array(y_train_df)
    y_test = np.array(y_test_df)
    
    print("X train type and shape: ", type(X_train), X_train.shape)
    print("y train type and shape: ", type(y_train), y_train.shape)
    
    print("X test type and shape: ", type(X_test), X_test.shape)
    print("y test type and shape: ", type(y_test), y_test.shape)
    print('-----------------------------------')
    
    
    return X_train, X_test, y_train, y_test

# %%
# TFIDF vectorizer

X_train_tf, X_test_tf, y_train_tf, y_test_tf = tfidfvectorize(X, y, max_df=0.95, min_df=0.001, ngram_range=(1,1), 
                                                 norm='l2', use_idf=True, smooth_idf=True, sublinear_tf=False)
# Out:
# Number of labels in the train set:
#  0    0.898286
# 1    0.101714
# Name: toxic_type, dtype: float64
# -----------------------------------
# Number of labels in the test set:
#  0    0.898289
# 1    0.101711
# Name: toxic_type, dtype: float64
# -----------------------------------
# X train type and shape:  <class 'numpy.ndarray'> (127613, 2958)
# y train type and shape:  <class 'numpy.ndarray'> (127613,)
# X test type and shape:  <class 'numpy.ndarray'> (31904, 2958)
# y test type and shape:  <class 'numpy.ndarray'> (31904,)
# -----------------------------------

# %%
# Logistic Regression model

clf = LogisticRegression(solver='lbfgs', max_iter=20000, random_state=1)
clf_model = clf.fit(X_train_tf, y_train_tf)

y_pred_train_tf = clf_model.predict(X_train_tf)

y_pred_test_tf = clf_model.predict(X_test_tf)

# %%
# Check the classification metrics for the test set

print("Test Classification Report")
print(classification_report(y_test_tf, y_pred_test_tf))
# Out:
# Test Classification Report
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     28659
#            1       0.91      0.63      0.75      3245
#
#     accuracy                           0.96     31904
#    macro avg       0.94      0.81      0.86     31904
# weighted avg       0.96      0.96      0.95     31904

# %%
# Check the classification metrics for the train set

print("Test Classification Report")
print(classification_report(y_train_tf, y_pred_train_tf))
# Out:
# Test Classification Report
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98    114633
#            1       0.92      0.63      0.75     12980
#
#     accuracy                           0.96    127613
#    macro avg       0.94      0.81      0.86    127613
# weighted avg       0.96      0.96      0.95    127613

# %% [markdown]
# ### 3.2.2. TF-IDF Vectorization - Parameters Evaluation

# %%
X = df['clean_text']
y = df['toxic_type']

#train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, random_state=1)

# %%
# Define the TF-IDF and Logistic Regression models with different parameters

pipeline = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', LogisticRegression(solver='lbfgs', max_iter=20000))])

parameters = {
    'tfidf__max_df': (0.95, 0.9, 0.85, 0.8),
    'tfidf__min_df': (0.0001, 0.0005, 0.001, 0.002),
    'tfidf__ngram_range': ((1,1), (2,2)),
    'tfidf__norm': ('l1', 'l2'),
    'tfidf__use_idf': (True, False),
    'tfidf__smooth_idf': (True, False),
    'tfidf__sublinear_tf': (True, False)
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, scoring='f1')
model_tf = grid_search.fit(X_train, y_train)

# %%
# Rank the results based on the f1-score metric

model_tf_results = pd.DataFrame(model_tf.cv_results_).sort_values(by='mean_test_score', ascending=False)
model_tf_results
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 172       3.052689      0.043315         0.512436        0.010285
# 300       3.061287      0.033217         0.507843        0.004753
# 40        3.311951      0.125871         0.561447        0.008321
# 44        3.381707      0.076519         0.572371        0.019592
# 424       3.041076      0.120493         0.508623        0.004067
# ..             ...           ...              ...             ...
# 497       5.244102      0.083984         0.689252        0.007039
# 247       5.337852      0.054408         0.694013        0.004190
# 371       5.277293      0.034150         0.685507        0.006322
# 113       5.350179      0.058524         0.709494        0.018204
# 373       5.270117      0.076613         0.691701        0.012542
#
#     param_tfidf__max_df param_tfidf__min_df param_tfidf__ngram_range  \
# 172                 0.9              0.0005                   (1, 1)
# 300                0.85              0.0005                   (1, 1)
# 40                 0.95              0.0005                   (1, 1)
# 44                 0.95              0.0005                   (1, 1)
# 424                 0.8              0.0005                   (1, 1)
# ..                  ...                 ...                      ...
# 497                 0.8               0.002                   (2, 2)
# 247                 0.9               0.002                   (2, 2)
# 371                0.85               0.002                   (2, 2)
# 113                0.95               0.002                   (2, 2)
# 373                0.85               0.002                   (2, 2)
#
#     param_tfidf__norm param_tfidf__smooth_idf param_tfidf__sublinear_tf  \
# 172                l2                   False                      True
# 300                l2                   False                      True
# 40                 l2                    True                      True
# 44                 l2                   False                      True
# 424                l2                    True                      True
# ..                ...                     ...                       ...
# 497                l1                    True                      True
# 247                l1                   False                     False
# 371                l1                    True                     False
# 113                l1                    True                      True
# 373                l1                   False                      True
#
#     param_tfidf__use_idf                                             params  \
# 172                 True  {'tfidf__max_df': 0.9, 'tfidf__min_df': 0.0005...
# 300                 True  {'tfidf__max_df': 0.85, 'tfidf__min_df': 0.000...
# 40                  True  {'tfidf__max_df': 0.95, 'tfidf__min_df': 0.000...
# 44                  True  {'tfidf__max_df': 0.95, 'tfidf__min_df': 0.000...
# 424                 True  {'tfidf__max_df': 0.8, 'tfidf__min_df': 0.0005...
# ..                   ...                                                ...
# 497                False  {'tfidf__max_df': 0.8, 'tfidf__min_df': 0.002,...
# 247                False  {'tfidf__max_df': 0.9, 'tfidf__min_df': 0.002,...
# 371                False  {'tfidf__max_df': 0.85, 'tfidf__min_df': 0.002...
# 113                False  {'tfidf__max_df': 0.95, 'tfidf__min_df': 0.002...
# 373                False  {'tfidf__max_df': 0.85, 'tfidf__min_df': 0.002...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 172           0.740230           0.759591           0.746905
# 300           0.740230           0.759591           0.746905
# 40            0.740230           0.759591           0.746905
# 44            0.740230           0.759591           0.746905
# 424           0.740230           0.759591           0.746905
# ..                 ...                ...                ...
# 497           0.059524           0.059502           0.052926
# 247           0.059524           0.059502           0.052926
# 371           0.059524           0.059502           0.052926
# 113           0.059524           0.059502           0.052926
# 373           0.059524           0.059502           0.052926
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 172           0.730402           0.748690         0.745164        0.009653
# 300           0.730402           0.748690         0.745164        0.009653
# 40            0.730402           0.748690         0.745164        0.009653
# 44            0.730402           0.748690         0.745164        0.009653
# 424           0.730402           0.748690         0.745164        0.009653
# ..                 ...                ...              ...             ...
# 497           0.021220           0.056569         0.049948        0.014567
# 247           0.021220           0.056569         0.049948        0.014567
# 371           0.021220           0.056569         0.049948        0.014567
# 113           0.021220           0.056569         0.049948        0.014567
# 373           0.021220           0.056569         0.049948        0.014567
#
#      rank_test_score
# 172                1
# 300                1
# 40                 1
# 44                 1
# 424                1
# ..               ...
# 497              497
# 247              497
# 371              497
# 113              497
# 373              497
#
# [512 rows x 20 columns]

# %%
# Classification report for the test set

y_pred_tf = model_tf.predict(X_test)
print(classification_report(y_test, y_pred_tf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     28659
#            1       0.92      0.66      0.77      3245
#
#     accuracy                           0.96     31904
#    macro avg       0.94      0.83      0.87     31904
# weighted avg       0.96      0.96      0.96     31904

# %%
# Classification report for the train set

y_pred_train_tf = model_tf.predict(X_train)
print(classification_report(y_train, y_pred_train_tf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98    114633
#            1       0.93      0.66      0.77     12980
#
#     accuracy                           0.96    127613
#    macro avg       0.95      0.83      0.87    127613
# weighted avg       0.96      0.96      0.96    127613

# %%
# The best model based on the f1-score metric

best_tfidf_model = model_tf.best_estimator_.steps[0][1]
print(best_tfidf_model)
# Out:
# TfidfVectorizer(max_df=0.95, min_df=0.0005, sublinear_tf=True)

# %%
# Summary of the results including fit time and score

tf = model_tf_results[['mean_fit_time', 'mean_score_time', 'params', 'mean_test_score']].head(1).transpose()
tf
# Out:
#                                                                172
# mean_fit_time                                             3.052689
# mean_score_time                                           0.512436
# params           {'tfidf__max_df': 0.9, 'tfidf__min_df': 0.0005...
# mean_test_score                                           0.745164

# %% [markdown]
# ### 3.3. Summary of Text Vecorization

# %% [markdown]
# The results for BOW and TF-IDF show that the perfromance of both model (in terms of f1-score metric) is very close. However, TF-IDF model performs better in terms of fit-time. The TF-IDF model is three times faster than the BOW model. Therefore, the TF-IDF technique is selected for the rest of modelling.

# %%
vec_sum = pd.concat([bow, tf], axis=1)
vec_sum.columns = ['BOW Terms Frequency', 'TF-IDF']
vec_sum
# Out:
#                                                                                         BOW Terms Frequency                                                                                                                                                 TF-IDF
# mean_fit_time                                                                                     10.432982                                                                                                                                               3.052689
# mean_score_time                                                                                    0.662657                                                                                                                                               0.512436
# params           {'countvect__max_df': 0.95, 'countvect__min_df': 0.0001, 'countvect__ngram_range': (1, 1)}  {'tfidf__max_df': 0.9, 'tfidf__min_df': 0.0005, 'tfidf__ngram_range': (1, 1), 'tfidf__norm': 'l2', 'tfidf__smooth_idf': False, 'tfidf__sublinear_t...
# mean_test_score                                                                                    0.756486                                                                                                                                               0.745164

# %%
print('The best vectorization model:')
model_tf.best_estimator_
# Out:
# The best vectorization model:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=0.0005,
#                                  sublinear_tf=True)),
#                 ('clf', LogisticRegression(max_iter=20000))])

# %% [markdown]
# ### 4. Evaluate Imbalanced Algorithm

# %% [markdown]
# As explained earlier, this dataset is imbalanced. The toxic-labeled comments are 10 percent of the non-toxic comments. This imbalance results in a small recall. In order to address the imbalance issue, I use oversamling, undersampling and combined techniques. Resampling techniques in conjunction with TF-IDF and GridSearch is employed to investigate the most optimal technique with the optimum sampling ratio.

# %% [markdown]
# ### 4.1. Oversampling Algorithms

# %% [markdown]
# ### 4.1.1. Random Oversampling

# %%
X = df['clean_text']
y = df['toxic_type']

#train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, random_state=1)

# %%
# TF-IDF text vectorization technique in conjunction with Random Oversampling and Logistic Regression techniques

pipeline = imbpipeline([('tfidf', TfidfVectorizer(max_df=0.95,
                            min_df=0.0005, sublinear_tf=True)),
                     ('over', RandomOverSampler(random_state=0)),
                     ('clf', LogisticRegression(solver='lbfgs', max_iter=20000))])

parameters = {
    'over__sampling_strategy': (1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3)
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, scoring='f1')
model_R1 = grid_search.fit(X_train, y_train)

# %%
# Rank the model based on the f1-score metric

model_R1_results = pd.DataFrame(model_R1.cv_results_).sort_values(by='mean_test_score', ascending=False)
model_R1_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_over__sampling_strategy                            params  split0_test_score  split1_test_score  split2_test_score  split3_test_score  split4_test_score  mean_test_score  std_test_score  rank_test_score
# 7       4.487857      0.214337         0.631202        0.022210                           0.3  {'over__sampling_strategy': 0.3}           0.771588           0.782678           0.774142           0.760073           0.775526         0.772801        0.007352                1
# 6       3.763166      0.164054         0.627233        0.036916                           0.4  {'over__sampling_strategy': 0.4}           0.768094           0.769608           0.768848           0.760953           0.770489         0.767598        0.003416                2
# 5       4.822719      0.647701         0.696380        0.089506                           0.5  {'over__sampling_strategy': 0.5}           0.758445           0.766158           0.761238           0.754214           0.758218         0.759655        0.003948                3
# 4       4.588342      0.360693         0.587250        0.015516                           0.6  {'over__sampling_strategy': 0.6}           0.748862           0.751494           0.748798           0.742684           0.748458         0.748059        0.002900                4
# 3       4.269987      0.423330         0.597438        0.051972                           0.7  {'over__sampling_strategy': 0.7}           0.738326           0.742964           0.735081           0.731716           0.735640         0.736745        0.003754                5
# 2       4.677800      0.349030         0.645635        0.029531                           0.8  {'over__sampling_strategy': 0.8}           0.728114           0.728239           0.727303           0.718440           0.724768         0.725373        0.003685                6
# 1       5.425109      0.342835         0.634329        0.035885                           0.9  {'over__sampling_strategy': 0.9}           0.717916           0.716442           0.718581           0.708757           0.716045         0.715548        0.003520                7
# 0       5.400107      0.176558         0.632666        0.015415                             1    {'over__sampling_strategy': 1}           0.707425           0.705136           0.707614           0.701428           0.707937         0.705908        0.002449                8

# %%
# Classification report for the test set

y_pred_R1 = model_R1.predict(X_test)
print(classification_report(y_test, y_pred_R1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     28659
#            1       0.81      0.77      0.79      3245
#
#     accuracy                           0.96     31904
#    macro avg       0.89      0.87      0.88     31904
# weighted avg       0.96      0.96      0.96     31904

# %%
# Classification report for the train set

y_pred_train_R1 = model_R1.predict(X_train)
print(classification_report(y_train, y_pred_train_R1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98    114633
#            1       0.82      0.79      0.81     12980
#
#     accuracy                           0.96    127613
#    macro avg       0.90      0.89      0.89    127613
# weighted avg       0.96      0.96      0.96    127613

# %%
# Summary of the results including fit time and score

R1_est = model_R1_results[['mean_fit_time', 'mean_score_time', 'params', 'mean_test_score']].head(1).transpose()
R1_est
# Out:
#                                                 7
# mean_fit_time                            4.487857
# mean_score_time                          0.631202
# params           {'over__sampling_strategy': 0.3}
# mean_test_score                          0.772801

# %% [markdown]
# Oversampling decreased the precision while increased the recall and f1-score.

# %% [markdown]
# ### 4.1.2. Synthetic Minority Oversampling Technique (SMOTE)

# %%
X = df['clean_text']
y = df['toxic_type']

#train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, random_state=1)

# %%
# TF-IDF text vectorization technique in conjunction with SMOTE and Logistic Regression techniques

pipeline = imbpipeline([('tfidf', TfidfVectorizer(max_df=0.95,
                            min_df=0.0005, sublinear_tf=True)),
                     ('over', SMOTE(random_state=0)),
                     ('clf', LogisticRegression(solver='lbfgs', max_iter=20000))])

parameters = {
    'over__sampling_strategy': (0.8, 0.7, 0.6, 0.5, 0.4, 0.3),
    'over__k_neighbors': (5, 10)
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, scoring='f1')
model_R2 = grid_search.fit(X_train, y_train)

# %%
# Rank the models based on the f1-score metric

model_R2_results = pd.DataFrame(model_R2.cv_results_).sort_values(by='mean_test_score', ascending=False)
model_R2_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_over__k_neighbors param_over__sampling_strategy                                                     params  split0_test_score  split1_test_score  split2_test_score  split3_test_score  split4_test_score  mean_test_score  std_test_score  rank_test_score
# 5        6.916010      0.212924         0.577729        0.010086                       5                           0.3   {'over__k_neighbors': 5, 'over__sampling_strategy': 0.3}           0.757796           0.766803           0.761472           0.748753           0.756640         0.758293        0.005942                1
# 11       6.905199      0.145154         0.569913        0.009699                      10                           0.3  {'over__k_neighbors': 10, 'over__sampling_strategy': 0.3}           0.753470           0.761127           0.756362           0.745871           0.754317         0.754229        0.004951                2
# 4        8.159111      0.720851         0.670125        0.139097                       5                           0.4   {'over__k_neighbors': 5, 'over__sampling_strategy': 0.4}           0.734873           0.746749           0.733223           0.729359           0.736746         0.736190        0.005814                3
# 10       7.255672      0.218931         0.578014        0.005960                      10                           0.4  {'over__k_neighbors': 10, 'over__sampling_strategy': 0.4}           0.732507           0.742733           0.733652           0.729490           0.731716         0.734020        0.004565                4
# 3        8.355792      0.634801         0.686703        0.116633                       5                           0.5   {'over__k_neighbors': 5, 'over__sampling_strategy': 0.5}           0.714286           0.722365           0.715109           0.715554           0.719806         0.717424        0.003124                5
# 9        7.269223      0.320980         0.581749        0.005386                      10                           0.5  {'over__k_neighbors': 10, 'over__sampling_strategy': 0.5}           0.715651           0.722614           0.715587           0.712014           0.714976         0.716168        0.003488                6
# 2        7.315658      0.687712         0.645427        0.037347                       5                           0.6   {'over__k_neighbors': 5, 'over__sampling_strategy': 0.6}           0.700318           0.705473           0.700050           0.702510           0.698859         0.701442        0.002335                7
# 8        6.948018      0.328178         0.585361        0.010913                      10                           0.6  {'over__k_neighbors': 10, 'over__sampling_strategy': 0.6}           0.697837           0.704095           0.701194           0.695961           0.700931         0.700004        0.002830                8
# 1        7.755950      0.325027         0.622015        0.025681                       5                           0.7   {'over__k_neighbors': 5, 'over__sampling_strategy': 0.7}           0.685355           0.691200           0.686794           0.686255           0.686505         0.687222        0.002047                9
# 7        7.164084      0.341037         0.584183        0.011843                      10                           0.7  {'over__k_neighbors': 10, 'over__sampling_strategy': 0.7}           0.683162           0.688960           0.684015           0.684873           0.684879         0.685178        0.001995               10
# 0        8.002378      0.334095         0.631969        0.034355                       5                           0.8   {'over__k_neighbors': 5, 'over__sampling_strategy': 0.8}           0.672193           0.680428           0.674309           0.677573           0.669473         0.674795        0.003867               11
# 6        7.669509      0.161289         0.575155        0.005863                      10                           0.8  {'over__k_neighbors': 10, 'over__sampling_strategy': 0.8}           0.669161           0.672747           0.673460           0.672155           0.671235         0.671751        0.001486               12

# %%
# Classification report for the test set

y_pred_R2 = model_R2.predict(X_test)
print(classification_report(y_test, y_pred_R2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     28659
#            1       0.78      0.77      0.77      3245
#
#     accuracy                           0.95     31904
#    macro avg       0.88      0.87      0.87     31904
# weighted avg       0.95      0.95      0.95     31904

# %%
# Classification report for the train set

y_pred_train_R2 = model_R2.predict(X_train)
print(classification_report(y_train, y_pred_train_R2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    114633
#            1       0.80      0.78      0.79     12980
#
#     accuracy                           0.96    127613
#    macro avg       0.89      0.88      0.88    127613
# weighted avg       0.96      0.96      0.96    127613

# %%
# Summary of the results including fit time and score

R2_est = model_R2_results[['mean_fit_time', 'mean_score_time', 'params', 'mean_test_score']].head(1).transpose()
R2_est
# Out:
#                                                                         5
# mean_fit_time                                                     6.91601
# mean_score_time                                                  0.577729
# params           {'over__k_neighbors': 5, 'over__sampling_strategy': 0.3}
# mean_test_score                                                  0.758293

# %% [markdown]
# ### 4.1.3. Adaptive Synthetic Sampling (ADASYN)

# %%
X = df['clean_text']
y = df['toxic_type']

#train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, random_state=1)

# %%
# TF-IDF text vectorization technique in conjunction with ADASYN and Logistic Regression techniques

pipeline = imbpipeline([('tfidf', TfidfVectorizer(max_df=0.95,
                            min_df=0.0005, sublinear_tf=True)),
                     ('over', ADASYN(random_state=0)),
                     ('clf', LogisticRegression(solver='lbfgs', max_iter=20000))])

parameters = {
    'over__sampling_strategy': (1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3),
    'over__n_neighbors': (5, 10)
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, scoring='f1')
model_R3 = grid_search.fit(X_train, y_train)

# %%
# Rank the models based on the f1-score metric

model_R3_results = pd.DataFrame(model_R3.cv_results_).sort_values(by='mean_test_score', ascending=False)
model_R3_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_over__n_neighbors param_over__sampling_strategy                                                     params  split0_test_score  split1_test_score  split2_test_score  split3_test_score  split4_test_score  mean_test_score  std_test_score  rank_test_score
# 15      32.366968      0.787638         0.518233        0.007229                       5                           0.3   {'over__n_neighbors': 5, 'over__sampling_strategy': 0.3}           0.742879           0.753002           0.743138           0.738204           0.743820         0.744209        0.004826                1
# 23      32.464678      0.544346         0.524949        0.008438                      10                           0.3  {'over__n_neighbors': 10, 'over__sampling_strategy': 0.3}           0.740559           0.750419           0.745486           0.735632           0.744239         0.743267        0.004953                2
# 7       28.986005      0.298114         0.523011        0.004547                       2                           0.3   {'over__n_neighbors': 2, 'over__sampling_strategy': 0.3}           0.735753           0.763693           0.732894           0.731159           0.734620         0.739624        0.012135                3
# 22      32.541456      0.568754         0.520001        0.010600                      10                           0.4  {'over__n_neighbors': 10, 'over__sampling_strategy': 0.4}           0.715234           0.725130           0.716176           0.718270           0.723300         0.719622        0.003920                4
# 6       29.608763      0.208661         0.523511        0.007007                       2                           0.4   {'over__n_neighbors': 2, 'over__sampling_strategy': 0.4}           0.712494           0.721642           0.714236           0.715915           0.718680         0.716593        0.003246                5
# 14      32.764342      0.384685         0.514650        0.006262                       5                           0.4   {'over__n_neighbors': 5, 'over__sampling_strategy': 0.4}           0.713719           0.719124           0.712968           0.713732           0.717249         0.715358        0.002400                6
# 5       29.528747      0.431455         0.527971        0.003840                       2                           0.5   {'over__n_neighbors': 2, 'over__sampling_strategy': 0
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97     28659
#            1       0.74      0.78      0.76      3245
#
#     accuracy                           0.95     31904
#    macro avg       0.86      0.88      0.87     31904
# weighted avg       0.95      0.95      0.95     31904

# %%
# Classification report for the train set

y_pred_train_R3 = model_R3.predict(X_train)
print(classification_report(y_train, y_pred_train_R3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97    114633
#            1       0.76      0.80      0.78     12980
#
#     accuracy                           0.95    127613
#    macro avg       0.87      0.88      0.88    127613
# weighted avg       0.95      0.95      0.95    127613

# %%
# Summary of the results including fit time and score

R3_est = model_R3_results[['mean_fit_time', 'mean_score_time', 'params', 'mean_test_score']].head(1).transpose()
R3_est
# Out:
#                                                                        15
# mean_fit_time                                                   32.366968
# mean_score_time                                                  0.518233
# params           {'over__n_neighbors': 5, 'over__sampling_strategy': 0.3}
# mean_test_score                                                  0.744209

# %% [markdown]
# ### 4.1.4. Borderline SMOTE

# %%
X = df['clean_text']
y = df['toxic_type']

#train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, random_state=1)

# %%
# TF-IDF text vectorization technique in conjunction with Borderline SMOTE and Logistic Regression techniques

pipeline = imbpipeline([('tfidf', TfidfVectorizer(max_df=0.95,
                            min_df=0.0005, sublinear_tf=True)),
                     ('over', BorderlineSMOTE(random_state=0)),
                     ('clf', LogisticRegression(solver='lbfgs', max_iter=20000))])

parameters = {
    'over__sampling_strategy': (0.6, 0.5, 0.4, 0.3),
    'over__k_neighbors': (5, 10),
    'over__m_neighbors': (5, 10),
    'over__kind': ('borderline-1', 'borderline-2')
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, scoring='f1')
model_R4 = grid_search.fit(X_train, y_train)

# %%
# Rank the models based on the f1-score metric

model_R4_results = pd.DataFrame(model_R4.cv_results_).sort_values(by='mean_test_score', ascending=False)
model_R4_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 31      31.570516      0.714157         0.517557        0.006706
# 15      31.524401      0.607368         0.517328        0.005470
# 11      31.147142      0.570845         0.523629        0.012498
# 27      31.212757      0.690695         0.523071        0.010903
# 7       31.525888      0.381679         0.520413        0.008443
# 19      30.799280      0.703867         0.525918        0.013078
# 23      31.705219      0.464030         0.542988        0.033430
# 3       31.069356      0.547218         0.516540        0.003253
# 14      32.212277      0.539310         0.514740        0.006699
# 30      31.963931      0.717496         0.522334        0.003557
# 10      30.929657      0.687218         0.520844        0.010970
# 26      31.212351      0.795761         0.516846        0.009421
# 6       31.920358      0.569851         0.522175        0.009587
# 22      31.753177      0.639567         0.516243        0.004571
# 2       31.081055      0.757221         0.522002        0.009181
# 18      30.661828      0.446041         0.516206        0.006321
# 13      32.181998      0.582997         0.523091        0.008773
# 29      31.920280      0.257077         0.517165        0.005522
# 9       31.876497      0.566670         0.518873        0.007759
# 25      31.525588      0.609836         0.520735        0.008118
# 5       32.106225      0.492700         0.518142        0.006464
# 21      32.020139      0.622901         0.517906        0.006360
# 1       31.659088      0.474976         0.519947        0.004765
# 17      31.625541      0.635898         0.517464        0.010484
# 12      32.560369      0.540907         0.524730        0.013022
# 28      32.389245      0.708777         0.519816        0.008407
# 8       32.179665      0.505284         0.521460        0.006977
# 24      32.389719      0.376007         0.518497        0.010353
# 4       32.364302      0.534380         0.521932        0.004265
# 20      32.332645      0.756912         0.523041        0.007996
# 0       32.069543      0.511060         0.522327        0.006636
# 16      31.820441      0.599159         0.522143        0.005748
#
#    param_over__k_neighbors param_over__kind param_over__m_neighbors  \
# 31                      10     borderline-2                      10
# 15                       5     borderline-2                      10
# 11                       5     borderline-2                       5
# 27                      10     borderline-2                       5
# 7                        5     borderline-1                      10
# 19                      10     borderline-1                       5
# 23                      10     borderline-1                      10
# 3                        5     borderline-1                       5
# 14                       5     borderline-2                      10
# 30                      10     borderline-2                      10
# 10                       5     borderline-2                       5
# 26                      10     borderline-2                       5
# 6                        5     borderline-1                      10
# 22                      10     borderline-1                      10
# 2                        5     borderline-1                       5
# 18                      10     borderline-1                       5
# 13                       5     borderline-2                      10
# 29                      10     borderline-2                      10
# 9                        5     borderline-2                       5
# 25                      10     borderline-2                       5
# 5                        5     borderline-1                      10
# 21                      10     borderline-1                      10
# 1                        5     borderline-1                       5
# 17                      10     borderline-1                       5
# 12                       5     borderline-2                      10
# 28                      10     borderline-2                      10
# 8                        5     borderline-2                       5
# 24                      10     borderline-2                       5
# 4                        5     borderline-1                      10
# 20                      10     borderline-1                      10
# 0                        5     borderline-1                       5
# 16                      10     borderline-1                       5
#
#    param_over__sampling_strategy  \
# 31                           0.3
# 15                           0.3
# 11                           0.3
# 27                           0.3
# 7                            0.3
# 19                           0.3
# 23                           0.3
# 3                            0.3
# 14                           0.4
# 30                           0.4
# 10                           0.4
# 26                           0.4
# 6                            0.4
# 22                           0.4
# 2                            0.4
# 18                           0.4
# 13                           0.5
# 29                           0.5
# 9                            0.5
# 25                           0.5
# 5                            0.5
# 21                           0.5
# 1                            0.5
# 17                           0.5
# 12                           0.6
# 28                           0.6
# 8                            0.6
# 24                           0.6
# 4                            0.6
# 20                           0.6
# 0                            0.6
# 16                           0.6
#
#                                                params  split0_test_score  \
# 31  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.759207
# 15  {'over__k_neighbors': 5, 'over__kind': 'border...           0.757432
# 11  {'over__k_neighbors': 5, 'over__kind': 'border...           0.757490
# 27  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.758660
# 7   {'over__k_neighbors': 5, 'over__kind': 'border...           0.741115
# 19  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.737253
# 23  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.739690
# 3   {'over__k_neighbors': 5, 'over__kind': 'border...           0.737568
# 14  {'over__k_neighbors': 5, 'over__kind': 'border...           0.736712
# 30  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.731054
# 10  {'over__k_neighbors': 5, 'over__kind': 'border...           0.730938
# 26  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.730749
# 6   {'over__k_neighbors': 5, 'over__kind': 'border...           0.719427
# 22  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.717886
# 2   {'over__k_neighbors': 5, 'over__kind': 'border...           0.713545
# 18  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.713617
# 13  {'over__k_neighbors': 5, 'over__kind': 'border...           0.709901
# 29  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.707647
# 9   {'over__k_neighbors': 5, 'over__kind': 'border...           0.707474
# 25  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.706037
# 5   {'over__k_neighbors': 5, 'over__kind': 'border...           0.698939
# 21  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.694311
# 1   {'over__k_neighbors': 5, 'over__kind': 'border...           0.695178
# 17  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.694716
# 12  {'over__k_neighbors': 5, 'over__kind': 'border...           0.687520
# 28  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.682652
# 8   {'over__k_neighbors': 5, 'over__kind': 'border...           0.686407
# 24  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.684656
# 4   {'over__k_neighbors': 5, 'over__kind': 'border...           0.680865
# 20  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.675547
# 0   {'over__k_neighbors': 5, 'over__kind': 'border...           0.674901
# 16  {'over__k_neighbors': 10, 'over__kind': 'borde...           0.673865
#
#     split1_test_score  split2_test_score  split3_test_score  \
#
results[['mean_fit_time', 'mean_score_time', 'params', 'mean_test_score']].head(1).transpose()
R4_est
# Out:
#                                                                                                                                31
# mean_fit_time                                                                                                           31.570516
# mean_score_time                                                                                                          0.517557
# params           {'over__k_neighbors': 10, 'over__kind': 'borderline-2', 'over__m_neighbors': 10, 'over__sampling_strategy': 0.3}
# mean_test_score                                                                                                          0.758929

# %% [markdown]
# ### 4.2. Summary of Oversampling

# %% [markdown]
# The results of four oversampling techniques show that their perfromance based on the f1-score metric is very close. However, Random Oversampling and SMOTE models perform better in terms of fit-time. These two models are six to eight times faster than the ADASYN and Borderline SMOTE models. Therefore, the Random Oversampling and SMOTE techniques are selected for the rest of modelling.

# %%
over_samp_sum = pd.concat([R1_est, R2_est, R3_est, R4_est], axis=1)
over_samp_sum.columns = ['Random Oversampling', 'SMOTE', 'ADASYN', 'Borederline SMOTE']
over_samp_sum
# Out:
#                               Random Oversampling                                                     SMOTE                                                    ADASYN                                                                                                 Borederline SMOTE
# mean_fit_time                            4.487857                                                   6.91601                                                 32.366968                                                                                                         31.570516
# mean_score_time                          0.631202                                                  0.577729                                                  0.518233                                                                                                          0.517557
# params           {'over__sampling_strategy': 0.3}  {'over__k_neighbors': 5, 'over__sampling_strategy': 0.3}  {'over__n_neighbors': 5, 'over__sampling_strategy': 0.3}  {'over__k_neighbors': 10, 'over__kind': 'borderline-2', 'over__m_neighbors': 10, 'over__sampling_strategy': 0.3}
# mean_test_score                          0.772801                                                  0.758293                                                  0.744209                                                                                                          0.758929

# %%
print('The best oversampling models: \n')
print(model_R1.best_estimator_, '\n')
print(model_R2.best_estimator_)
# Out:
# The best oversampling models:
#
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=0.0005,
#                                  sublinear_tf=True)),
#                 ('over',
#                  RandomOverSampler(random_state=0, sampling_strategy=0.3)),
#                 ('clf', LogisticRegression(max_iter=20000))])
#
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=0.0005,
#                                  sublinear_tf=True)),
#                 ('over', SMOTE(random_state=0, sampling_strategy=0.3)),
#                 ('clf', LogisticRegression(max_iter=20000))])

# %% [markdown]
# ### 4.3. Undersampling Algorithms

# %% [markdown]
# In this section, undersampling techniques are investigated.

# %% [markdown]
# ### 4.3.1. Random Undersampling

# %%
X = df['clean_text']
y = df['toxic_type']

#train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, random_state=1)

# %%
# TF-IDF text vectorization technique in conjunction with Random Undersampling and Logistic Regression techniques

pipeline = imbpipeline([('tfidf', TfidfVectorizer(max_df=0.95,
                            min_df=0.0005, sublinear_tf=True)),
                     ('under', RandomUnderSampler(random_state=0)),
                     ('clf', LogisticRegression(solver='lbfgs', max_iter=20000))])

parameters = {
    'under__sampling_strategy': (1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3),
    'under__replacement': (False, True)
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, scoring='f1')
model_U1 = grid_search.fit(X_train, y_train)

# %%
# Rank the models based on the f1-score metric

model_U1_results = pd.DataFrame(model_U1.cv_results_).sort_values(by='mean_test_score', ascending=False)
model_U1_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_under__replacement param_under__sampling_strategy                                                          params  split0_test_score  split1_test_score  split2_test_score  split3_test_score  split4_test_score  mean_test_score  std_test_score  rank_test_score
# 7        2.744475      0.071310         0.527599        0.014016                    False                            0.3  {'under__replacement': False, 'under__sampling_strategy': 0.3}           0.765827           0.777936           0.771569           0.759221           0.776849         0.770280        0.007008                1
# 15       2.609675      0.019024         0.526023        0.007193                     True                            0.3   {'under__replacement': True, 'under__sampling_strategy': 0.3}           0.764969           0.774924           0.770672           0.756846           0.774480         0.768378        0.006782                2
# 6        2.487244      0.086824         0.530389        0.003566                    False                            0.4  {'under__replacement': False, 'under__sampling_strategy': 0.4}           0.764158           0.772270           0.767091           0.756906           0.767139         0.765513        0.005034                3
# 14       2.432507      0.033223         0.519465        0.002599                     True                            0.4   {'under__replacement': True, 'under__sampling_strategy': 0.4}           0.760983           0.771605           0.766007           0.752107           0.766344         0.763409        0.006575                4
# 5        2.531917      0.086102         0.535679        0.010193                    False                            0.5  {'under__replacement': False, 'under__sampling_strategy': 0.5}           0.753387           0.762259           0.754915           0.751513           0.758493         0.756113        0.003833                5
# 13       2.439076      0.036471         0.524021        0.012172                     True                            0.5   {'under__replacement': True, 'under__sampling_strategy': 0.5}           0.753977           0.758011           0.758957           0.748029           0.754147         0.754624        0.003857                6
# 4        2.608921      0.158850         0.550738        0.018398                    False                            0.6  {'under__replacement': False, 'under__sampling_strategy': 0.6}           0.740662           0.747904           0.744589           0.742402           0.749243         0.744960        0.003230                7
# 12       2.461128      0.076037         0.519670        0.009585                     True                            0.6   {'under__replacement': True, 'under__sampling_strategy': 0.6}           0.738353           0.740819           0.743083           0.736577           0.739629         0.739692        0.002203                8
# 3        3.282974      0.834006         0.679792        0.132182                    False                            0.7  {'under__replacement': False, 'under__sampling_strategy': 0.7}           0.725394           0.731113           0.731902           0.726296           0.732491         0.729439        0.002981                9
# 11       2.354479      0.018382         0.526057        0.013062                     True                            0.7   {'under__replacement': True, 'under__sampling_strategy': 0.7}           0.723426           0.728257           0.725490           0.723803           0.728479         0.725891        0.002140               10
# 2        2.530046      0.126742         0.553478        0.027826                    False                            0.8  {'under__replacement': False, 'under__sampling_strategy': 0.8}           0.711748           0.716310           0.717812           0.712954           0.717755         0.715316        0.002509               11
# 10       2.338556      0.019509         0.520024        0.007254                     True                            0.8   {'under__replacement': True, 'under__sampling_strategy': 0.8}           0.708536           0.712516           0.708911           0.711474           0.712961         0.710880        0.001829               12
# 1        2.739443      0.166062         0.618887        0.040198                    False                            0.9  {'under__replacement': False, 'under__sampling_strategy': 0.9}           0.694671           0.700095           0.704878           0.698895           0.700079         0.699724        0.003257               13
# 9        2.348374      0.037925         0.522990        0.005749                     True                            0.9   {'under__replacement': True, 'under__sampling_strategy': 0.9}           0.693584           0.698283           0.694365           0.696337           0.695339         0.695581        0.001637               14
# 0        2.886340      0.082255         0.613255        0.054258                    False                              1    {'under__replacement': False, 'under__sampling_strategy': 1}           0.680400           0.684444           0.690020           0.679483           0.683564         0.683582        0.003718               15
# 8        2.338982      0.023434         0.526596        0.013659                     True                              1     {'under__replacement': True, 'under__sampling_strategy': 1}           0.680800           0.684731           0.679570           0.679176           0.679120         0.680679        0.002115               16

# %%
# Classification report of the test set

y_pred_U1 = model_U1.predict(X_test)
print(classification_report(y_test, y_pred_U1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     28659
#            1       0.83      0.75      0.79      3245
#
#     accuracy                           0.96     31904
#    macro avg       0.90      0.87      0.88     31904
# weighted avg       0.96      0.96      0.96     31904

# %%
# Classification report of the train set

y_pred_train_U1 = model_U1.predict(X_train)
print(classification_report(y_train, y_pred_train_U1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    114633
#            1       0.83      0.76      0.80     12980
#
#     accuracy                           0.96    127613
#    macro avg       0.90      0.87      0.89    127613
# weighted avg       0.96      0.96      0.96    127613

# %%
# Summary of the results including fit time and score

U1_est = model_U1_results[['mean_fit_time', 'mean_score_time', 'params', 'mean_test_score']].head(1).transpose()
# %%
X = df['clean_text']
y = df['toxic_type']

#train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, random_state=1)

# %%
pipeline = imbpipeline([('tfidf', TfidfVectorizer(max_df=0.95,
                            min_df=0.0005, sublinear_tf=True)),
                     ('under', EditedNearestNeighbours()),
                     ('clf', LogisticRegression(solver='lbfgs', max_iter=20000))])

parameters = {
#     'under__sampling_strategy': (0.7, 0.6, 0.5, 0.4, 0.3),
    'under__n_neighbors': (3, 5, 10)
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, scoring='f1')
model_U3 = grid_search.fit(X_train, y_train)

# %%
model_U3_results = pd.DataFrame(model_U3.cv_results_).sort_values(by='mean_test_score', ascending=False)
model_U3_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_under__n_neighbors                      params  split0_test_score  split1_test_score  split2_test_score  split3_test_score  split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0     324.979790     14.775089         0.621453        0.050824                        3   {'under__n_neighbors': 3}           0.764854           0.773172           0.771405           0.753820           0.775527         0.767756        0.007819                1
# 1     288.217242      5.200355         0.537285        0.013028                        5   {'under__n_neighbors': 5}           0.756083           0.766504           0.761923           0.750049           0.764580         0.759828        0.006020                2
# 2     322.754941     14.225493         0.635863        0.077760                       10  {'under__n_neighbors': 10}           0.652092           0.667565           0.647110           0.655076           0.654561         0.655281        0.006759                3

# %%
y_pred_U3 = model_U3.predict(X_test)
print(classification_report(y_test, y_pred_U3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     28659
#            1       0.84      0.74      0.79      3245
#
#     accuracy                           0.96     31904
#    macro avg       0.91      0.86      0.88     31904
# weighted avg       0.96      0.96      0.96     31904

# %%
y_pred_train_U3 = model_U3.predict(X_train)
print(classification_report(y_train, y_pred_train_U3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    114633
#            1       0.85      0.74      0.79     12980
#
#     accuracy                           0.96    127613
#    macro avg       0.91      0.86      0.88    127613
# weighted avg       0.96      0.96      0.96    127613

# %%
# Summary of the results including fit time and score

U3_est = model_U3_results[['mean_fit_time', 'mean_score_time', 'params', 'mean_test_score']].head(1).transpose()
U3_est
# Out:
#                                          0
# mean_fit_time                    324.97979
# mean_score_time                   0.621453
# params           {'under__n_neighbors': 3}
# mean_test_score                   0.767756

# %% [markdown]
# ### 4.4. Summary of Undersampling

# %% [markdown]
# The results of four undersampling techniques show that their perfromance based on the f1-score metric is very close. However, Random undersampling and NearMiss models perform better in terms of fit-time. These two models are considerably faster than the EdittedNearestNeighbor model. Therefore, the Random undersampling and EdittedNearestNeighbor techniques are selected for the rest of modelling.

# %%
over_samp_sum = pd.concat([U1_est, U2_est, U3_est], axis=1)
over_samp_sum.columns = ['Random Undersampling', 'NearMiss', 'Editted Nearest Neighbor']
over_samp_sum
# Out:
#                                                            Random Undersampling                                                                                  NearMiss   Editted Nearest Neighbor
# mean_fit_time                                                          2.744475                                                                                   25.4518                  324.97979
# mean_score_time                                                        0.527599                                                                                  0.533922                   0.621453
# params           {'under__replacement': False, 'under__sampling_strategy': 0.3}  {'under__n_neighbors': 5, 'under__n_neighbors_ver3': 3, 'under__sampling_strategy': 0.4}  {'under__n_neighbors': 3}
# mean_test_score                                                         0.77028                                                                                  0.770401                   0.767756

# %%
print('The best oversampling models: \n')
print(model_U1.best_estimator_, '\n')
print(model_U2.best_estimator_)
# Out:
# The best oversampling models:
#
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=0.0005,
#                                  sublinear_tf=True)),
#                 ('under',
#                  RandomUnderSampler(random_state=0, sampling_strategy=0.3)),
#                 ('clf', LogisticRegression(max_iter=20000))])
#
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=0.0005,
#                                  sublinear_tf=True)),
#                 ('under', NearMiss(n_neighbors=5, sampling_strategy=0.4)),
#                 ('clf', LogisticRegression(max_iter=20000))])

# %% [markdown]
# ### 4.5. Combined Methods

# %% [markdown]
# #### 4.5.1. SMOTETomek

# %%
X = df['clean_text']
y = df['toxic_type']

#train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    stratify=y, random_state=1)

# %%
pipeline = imbpipeline([('tfidf', TfidfVectorizer(max_df=0.95,
                            min_df=0.0005, sublinear_tf=True)),
                     ('combine', SMOTETomek(random_state=0)),
                     ('clf', LogisticRegression(solver='lbfgs', max_iter=20000))])

parameters = {
    'combine__sampling_strategy': np.arange(0.1, 1.1, 0.1)
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, scoring='f1')
model_Com1 = grid_search.fit(X_train, y_train)
# Out:
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 277, in fit
#     Xt, yt, fit_params = self._fit(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 236, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 403, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 580, in check_sampling_strategy
#     _sampling_strategy_float(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 402, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 277, in fit
#     Xt, yt, fit_params = self._fit(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 236, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 403, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 580, in check_sampling_strategy
#     _sampling_strategy_float(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 402, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 277, in fit
#     Xt, yt, fit_params = self._fit(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 236, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 403, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 580, in check_sampling_strategy
#     _sampling_strategy_float(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 402, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 277, in fit
#     Xt, yt, fit_params = self._fit(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 236, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 403, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 580, in check_sampling_strategy
#     _sampling_strategy_float(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 402, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 277, in fit
#     Xt, yt, fit_params = self._fit(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 236, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/pipeline.py", line 403, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 580, in check_sampling_strategy
#     _sampling_strategy_float(
#   File "/Users/zori/opt/anaconda3/lib/python3.9/site-packages/imblearn/utils/_validation.py", line 402, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/zori/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan 0.76814975 0.75761241 0.73624319 0.7177287  0.70137543
#  0.68767943 0.67471342 0.66207196 0.65153494]
#   warnings.warn(

# %%
model_Com1_results = pd.DataFrame(model_Com1.cv_results_).sort_values(by='mean_test_score', ascending=False)
model_Com1_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_combine__sampling_strategy                                               params  split0_test_score  split1_test_score  split2_test_score  split3_test_score  split4_test_score  mean_test_score  std_test_score  rank_test_score
# 1     355.357150     10.866472         0.658165        0.064357                              0.2                  {'combine__sampling_strategy': 0.2}           0.764780           0.777871           0.772101           0.757186           0.768810         0.768150        0.006959                1
# 2     397.953100     15.226109         0.614368        0.067283                              0.3  {'combine__sampling_strategy': 0.30000000000000004}           0.757160           0.766472           0.758839           0.749101           0.756491         0.757612        0.005548                2
# 3     413.826744     14.318603         0.556977        0.018961                              0.4                  {'combine__sampling_strategy': 0.4}           0.733736           0.746879           0.733052           0.730035           0.737514         0.736243        0.005827                3
# 4     511.415184     12.425874         0.603629        0.045747                              0.5                  {'combine__sampling_strategy': 0.5}           0.714633           0.722241           0.716084           0.715199           0.720486         0.717729        0.003055                4
# 5     538.704327     28.443737         0.585721        0.048877                              0.6                  {'combine__sampling_strategy': 0.6}           0.700669           0.704323           0.699664           0.702088           0.700133         0.701375        0.001683                5
# 6     647.655594     19.195375         0.635477        0.120809                              0.7   {'combine__sampling_strategy': 0.7000000000000001}           0.686331           0.691433           0.687136           0.686348           0.687148         0.687679        0.001911                6
# 7     660.522340      3.901744         0.547686        0.003704                              0.8                  {'combine__sampling_strategy': 0.8}           0.672508           0.680012           0.673998           0.677471           0.669577         0.674713        0.003672                7
# 8     811.929559     36.339873         0.639303        0.057567                              0.9                  {'combine__sampling_strategy': 0.9}           0.661785           0.664453           0.663187           0.661937           0.658998         0.662072        0.001814                8
# 9     839.679736     32.388786         0.582770        0.055965                              1.0                  {'combine__sampling_strategy': 1.0}           0.648176           0.655142           0.652902           0.653301           0.648154         0.651535        0.002854                9
# 0       2.561076      0.112182         0.000000        0.000000                              0.1                  {'combine__sampling_strategy': 0.1}                NaN                NaN                NaN                NaN                NaN              NaN             NaN               10
